# %% [markdown]
# # Dataset Analysis

# %% [markdown]
# ## List of the fields

# %% [markdown]
# Before diving into the code, let's give a look to the fields and the type of data that each of them contains (The following code performs a kind of SELECT DISTINCT of the fields):
#
# **NOTE!** 🟢
# The field "*Example Content*" contains 5 random samples of the field content. These samples are not aggregated.

# %% [markdown]
# | **FIELD** 	| **TYPE** 	| **TO PARSE** 	| **Are we going to use it?** 	| **Example Content** 	|
# |---	|:---:	|:---:	|:---:	|---	|
# | age_ratings 	|  	| 🟠 	| ✅ 	| [[114607, 114609, 126972, 126973, 126974, 127011], [39395, 54394], [65532], [67799], [57121, 58326, 91135, 93494, 110841, 126135]] 	|
# | aggregated_rating 	| float 	|  	| ❌ 	| [65.0, 73.25, 82.5, 69.0, 70.93333333333334] 	|
# | aggregated_rating_count 	|  	|  	| ❌ 	| [3, 4, 3, 1, 17] 	|
# | alternative_names 	|  	|  	| ❌ 	| [[36941, 36942, 127468], [65648, 105850, 117666], [120224], [97398], [106570, 116583]] 	|
# | artworks 	|  	|  	| ❌ 	| [[96775], [14195], [9728], [115992], [11731, 68424]] 	|
# | bundles 	|  	|  	| ❌ 	| [[263897], [230749, 230823, 230826], [251322], [29208], [136262, 164674, 164778, 219003, 230498, 230702]] 	|
# | category 	|  	| 🟠 	| ✅ 	| [0, 0, 0, 0, 0] 	|
# | checksum 	|  	|  	| ❌ 	| ['4e87d634-9146-2025-b09b-9e4ea1e04764', '00e38d21-91cd-3082-4737-7978c44e33e2', '40916ead-d6e4-99f3-ab54-d653605a984b', '489ad4d0-e2f2-09e0-3bae-a76091559c44', 'bc043ffb-ad60-6bd0-801b-55a6141e773c'] 	|
# | collection 	|  	| 🟠 	|  	| [602, 2449, 7103, 7856, 559] 	|
# | collections 	|  	| 🟠 	|  	| [[602], [18], [18], [39, 7197], [39]] 	|
# | cover 	|  	|  	| ❌ 	| [280467, 247255, 272120, 192106, 326638] 	|
# | created_at 	|  	|  	| ❌ 	| [1673878007, 1621112209, 1499434349, 1517405808, 1521818623] 	|
# | dlcs 	| game_id 	|  	|  	| [[171610], [8219, 222679, 239352], [172092], [212363, 212364, 212365], [140056, 140057, 140058]] 	|
# | expanded_games (?) 	| game_id 	|  	|  	| [[135286], [30251], [78807], [57658], [124492]] 	|
# | expansions (?) 	| game_id 	|  	|  	| [[171428], [19540, 19551, 26852], [44596], [171147], [18442]] 	|
# | external_games 	|  	| game_id of other platforms 	| ❌ 	| [[2639959, 2677882, 2677897, 2677919, 2678595], [2011978], [51807, 154169, 1867507], [221231, 1748471, 1991656], [1989881]] 	|
# | first_release_date 	|  	|  	| ✅ 	| [1677110400, 1610928000, 1019001600, 1559952000, 1644796800] 	|
# | follows 	|  	| followers of the game 	|  	| [1, 1, 1, 63, 244] 	|
# | forks (?) 	|  	|  	|  	| [[79074, 109134, 133635, 147176, 151170, 176876, 197828, 246736, 255413], [235313], [141686], [67248], [142289]] 	|
# | franchise 	|  	| 🟠 	|  	| [361, 9, 102, 299, 105] 	|
# | franchises 	|  	| 🟠 	|  	| [[1651, 3134], [872, 874], [3390], [509, 977], [1351]] 	|
# | game_engines 	|  	| 🟠 	| ❌ 	| [[1543], [427], [439], [72], [10]] 	|
# | game_localizations 	|  	| 🟠 	| ❌ 	| [[2026, 13450], [4006, 19440], [14535], [1863, 3984], [11783, 20873]] 	|
# | game_modes 	|  	| 🟠 	| ✅ 	| [[1, 2], [1, 2], [1], [1], [1]] 	|
# | genres 	|  	| 🟠 	| ✅ 	| [[15], [4, 31, 33], [7, 13, 33], [9, 33], [31, 32]] 	|
# | hypes 	|  	| number of followers before release date 	| ❌ 	| [1, 1, 26, 2, 2] 	|
# | id 	| game_id 	| id_of_IGDB 	| ✅ 	| [231577, 147666, 44711, 85450, 95080] 	|
# | involved_companies 	|  	| 🟠 	| ✅ 	| [[102978, 102979], [85230], [154613], [229692, 229693], [194995, 194996]] 	|
# | keywords 	|  	|  	| ❌ 	| [[1699, 2152, 4137, 4438, 5029, 5188, 5189, 10098, 13115], [101], [78, 394, 960, 1033, 2458], [30750, 33125], [1308, 3257]] 	|
# | language_supports 	|  	| 🟠 	| ✅ 	| [[504844], [784416, 784417, 784418, 784419], [108775, 108776], [430843, 430844, 430845], [46076, 46078, 46080, 46082, 46084, 46086, 46088, 46090, 46092, 46094, 46096, 46098, 46100, 46102, 46104, 46106, 46108, 46110, 46112, 46114, 148503, 148505, 148507, 148513, 148515]] 	|
# | multiplayer_modes 	|  	|  	| ❌ 	| [[11174, 11175], [18654], [20006], [7037, 7982, 12750, 21945], [22267]] 	|
# | name 	|  	|  	| ✅ 	| ['Blood Bowl 3: Black Orcs Edition', 'Shinobi Blade', 'DDRMax2: Dance Dance Revolution', 'Transformers Prime: The Game', 'Dotra'] 	|
# | parent_game 	| game_id 	|  	|  	| [110980, 46584, 198295, 231152, 107843] 	|
# | platforms 	|  	| 🟠 	| ✅ 	| [[49, 169], [130], [8, 52], [34, 39], [6]] 	|
# | player_perspectives 	|  	|  	| ❌ 	| [[6], [2, 4], [1, 7], [1], [2]] 	|
# | ports 	|  	|  	| ❌ 	| [[73949, 144894], [10], [251353], [122871], [8809]] 	|
# | rating 	|  	|  	| ❌ 	| [70.0, 78.83709512164174, 60.0, 40.0, 50.0] 	|
# | rating_count 	|  	|  	| ❌ 	| [0, 102, 0, 0, 0] 	|
# | release_dates 	|  	|  	| ❌ 	| [[455316, 455317], [249798, 340666], [201923, 201924, 201925], [511087], [345917, 387770, 387772, 387773, 389364, 406085]] 	|
# | remakes 	|  	|  	| ❌ 	| [[18189], [222995], [93192], [1181], [245057]] 	|
# | remasters 	|  	|  	| ❌ 	| [[265060], [145817, 158981], [11218], [203435], [267307]] 	|
# | reviews.author 	|  	|  	| ✅ 	| ['maskedgingerjock', 'MisterEcho', 'Ziggy The Adventurer', 'Obey the Fist!', 'Sixth'] 	|
# | reviews.postedDate 	|  	|  	| ✅ 	| ['18 September', '4 September', '3 September', '31 March, 2022\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSteam Key', '21 September, 2022'] 	|
# | reviews.recommended 	|  	|  	| ✅ 	| [False, True, None, False, True] 	|
# | reviews.review 	|  	|  	| ✅ 	| ['This game is horrible. This game is boring.You can get both endings in under 10 minutes.There is no ...', 'https://youtu.be/dbbmoI0O5UgPretty nice game if you like indie walking simulator games with some jum...', "Plays fine, looks okay, very limited options, no body, can't jump or crouch, can be finished in abou...", 'Warning: Asset Flip!Pet Puzzle is a Unity Asset flip, what Valve calls a "fake game". 	|
# | screenshots 	|  	|  	| ❌ 	| [[1002202, 1002203, 1002204, 1002205, 1002206, 1002207], [447897, 447898, 447899, 447900, 447901], [338676, 338677, 338678, 390639, 390640], [1128097, 1128099, 1128104, 1128107, 1128111], [311510, 311511, 311512, 311513, 311514]] 	|
# | similar_games 	| game_id 	|  	|  	| [[17613, 24620, 36269, 36346, 65827, 76340, 77038, 77597, 111043, 112754], [10605, 56033, 87622, 96217, 101608, 103292, 103369, 111130, 114145, 117533], [3679, 18981, 27378, 38967, 43218, 43488, 43680, 63933, 73042, 76901], [18115, 19222, 25905, 41349, 85804, 87170, 87507, 90788, 90965, 95776], [13189, 25222, 27266, 55282, 75948, 87975, 96217, 106992, 111130, 121217]] 	|
# | slug 	|  	|  	| ❌ 	| ['blood-bowl-3-black-orcs-edition', 'shinobi-blade', 'ddrmax2-dance-dance-revolution', 'transformers-prime-the-game', 'dotra'] 	|
# | standalone_expansions 	|  	|  	| ❌ 	| [[146969], [3735], [27898], [203628], [128415]] 	|
# | status 	|  	| 🟠 	| ✅ 	| [8, 4, 4, 4, 4] 	|
# | steam 	|  	|  	| ❌ 	| ['2557720', '1092080', '1667954', '1851020', '2009730'] 	|
# | storyline 	|  	|  	| ❌ 	| ['In the ancient, mysterious world of the Jade Empire, you train under your master’s watchful eye and ...', 'From the frigid climes of Norsca to the arid wastes of the southern Badlands, The Old World echoes t...', 'You live in a peaceful world that has triumphed over a giant alien invasion. To pay off your debts, ...', "You who are unqualified to drink Meng Po's soup, you have been chosen for the game of life. Three wo...", 'Following the end of the Galactic Civil War, the bright lights of The Arena burst into life and offe...'] 	|
# | summary 	|  	|  	| ✅ 	| ["Fashion is not exactly a priority for Black Orcs… but intimidation, on the other hand, now we're tal...", 'Shinobi Blade is an action-packed game, lets you play the role of a teenage ninja who sneaked out of...', 'The dance floor kicks into overdrive with DDRMAX2 Dance Dance Revolution. It is the latest installme...', 'Shoot bubbles and match colors to pop your way up to victory in this bubble shooting adventure, win ...', 'A missing father, a mysterious murder, paintings depicting missing children. Horror game in which th...'] 	|
# | tags 	|  	| 🟠 	| ❌ 	| [[268435471], [1, 268435460, 268435487, 268435489], [40, 268435463, 268435469, 268435489, 536872611, 536873064, 536875049, 536875350, 536875941, 536876100, 536876101, 536881010, 536884027], [268435465, 268435489], [268435487, 268435488]] 	|
# | themes 	|  	|  	| ❌ 	| [[1], [40], [17, 22, 27], [1], [1]] 	|
# | total_rating 	|  	|  	| ✅ 	| [65.0, 70.0, 73.25, 80.66854756082087, 60.0] 	|
# | total_rating_count 	|  	|  	| ✅ 	| [3, 0, 4, 105, 0] 	|
# | updated_at 	|  	|  	| ❌ 	| [1699266775, 1698219001, 1696215459, 1670993154, 1670992528] 	|
# | url 	|  	|  	| ❌ 	| ['https://www.igdb.com/games/blood-bowl-3-black-orcs-edition', 'https://www.igdb.com/games/shinobi-blade', 'https://www.igdb.com/games/ddrmax2-dance-dance-revolution', 'https://www.igdb.com/games/transformers-prime-the-game', 'https://www.igdb.com/games/dotra'] 	|
# | version_parent 	|  	|  	| ❌ 	| [138137, 24115, 139736, 138137, 28856] 	|
# | version_title 	|  	|  	| ❌ 	| ['Black Orcs Edition', 'Platinum Edition', "Collector's Edition", 'Imperial Nobility Edition', 'Digital Deluxe Edition'] 	|
# | videos 	|  	|  	| ❌ 	| [[37984], [64610], [28099], [35464], [28553]] 	|
# | websites 	|  	|  	| ❌ 	| [[455726], [145653, 145654, 145655, 354472], [445624], [429116], [407422]] 	|

# %%
import json

def explore_keys_with_examples(data, path='', examples=None):
    """
    Funzione ricorsiva per esplorare le chiavi in un dataset JSON e raccogliere esempi.
    
    :param data: Il dataset o una parte di esso.
    :param path: Il percorso corrente delle chiavi.
    :param examples: Un dizionario che tiene traccia degli esempi per ogni chiave.
    :return: None. Modifica il dizionario `examples` direttamente.
    """
    if examples is None:
        examples = {}

    if isinstance(data, dict):
        for k, v in data.items():
            new_path = f"{path}.{k}" if path else k
            if new_path not in examples:
                examples[new_path] = []
            if len(examples[new_path]) < 5:
                # Tronca il testo se è troppo lungo
                if isinstance(v, str) and len(v) > 100:
                    v = v[:100] + "..."
                examples[new_path].append(v)
            explore_keys_with_examples(v, new_path, examples)

    elif isinstance(data, list):
        for item in data:
            explore_keys_with_examples(item, path, examples)

    return examples

# Carica il dataset JSON
with open('./../games_dataset_reviews_transformed.json', 'r') as file:
    json_data = json.load(file)

# Esplora le chiavi e raccogli esempi
examples = explore_keys_with_examples(json_data)

# Stampa i risultati
for key in sorted(examples):
    #print(f"{key}: {examples[key]}")
    print(f"{examples[key]}")
# Out:
# [[114607, 114609, 126972, 126973, 126974, 127011], [39395, 54394], [65532], [67799], [57121, 58326, 91135, 93494, 110841, 126135]]
# [65.0, 73.25, 82.5, 69.0, 70.93333333333334]
# [3, 4, 3, 1, 17]
# [[36941, 36942, 127468], [65648, 105850, 117666], [120224], [97398], [106570, 116583]]
# [[96775], [14195], [9728], [115992], [11731, 68424]]
# [[263897], [230749, 230823, 230826], [251322], [29208], [136262, 164674, 164778, 219003, 230498, 230702]]
# [0, 0, 0, 0, 0]
# ['4e87d634-9146-2025-b09b-9e4ea1e04764', '00e38d21-91cd-3082-4737-7978c44e33e2', '40916ead-d6e4-99f3-ab54-d653605a984b', '489ad4d0-e2f2-09e0-3bae-a76091559c44', 'bc043ffb-ad60-6bd0-801b-55a6141e773c']
# [602, 2449, 7103, 7856, 559]
# [[602], [18], [18], [39, 7197], [39]]
# [280467, 247255, 272120, 192106, 326638]
# [1673878007, 1621112209, 1499434349, 1517405808, 1521818623]
# [[171610], [8219, 222679, 239352], [172092], [212363, 212364, 212365], [140056, 140057, 140058]]
# [[135286], [30251], [78807], [57658], [124492]]
# [[171428], [19540, 19551, 26852], [44596], [171147], [18442]]
# [[2639959, 2677882, 2677897, 2677919, 2678595], [2011978], [51807, 154169, 1867507], [221231, 1748471, 1991656], [1989881]]
# [1677110400, 1610928000, 1019001600, 1559952000, 1644796800]
# [1, 1, 1, 63, 244]
# [[79074, 109134, 133635, 147176, 151170, 176876, 197828, 246736, 255413], [235313], [141686], [67248], [142289]]
# [361, 9, 102, 299, 105]
# [[1651, 3134], [872, 874], [3390], [509, 977], [1351]]
# [[1543], [427], [439], [72], [10]]
# [[2026, 13450], [4006, 19440], [14535], [1863, 3984], [11783, 20873]]
# [[1, 2], [1, 2], [1], [1], [1]]
# [[15], [4, 31, 33], [7, 13, 33], [9, 33], [31, 32]]
# [1, 1, 26, 2, 2]
# [231577, 147666, 44711, 85450, 95080]
# [[102978, 102979], [85230], [154613], [229692, 229693], [194995, 194996]]
# [[1699, 2152, 4137, 4438, 5029, 5188, 5189, 10098, 13115], [101], [78, 394, 960, 1033, 2458], [30750, 33125], [1308, 3257]]
# [[504844], [784416, 784417, 784418, 784419], [108775, 108776], [430843, 430844, 430845], [46076, 46078, 46080, 46082, 46084, 46086, 46088, 46090, 46092, 46094, 46096, 46098, 46100, 46102, 46104, 46106, 46108, 46110, 46112, 46114, 148503, 148505, 148507, 148513, 148515]]
# [[11174, 11175], [18654], [20006], [7037, 7982, 12750, 21945], [22267]]
# ['Blood Bowl 3: Black Orcs Edition', 'Shinobi Blade', 'DDRMax2: Dance Dance Revolution', 'Transformers Prime: The Game', 'Dotra']
# [110980, 46584, 198295, 231152, 107843]
# [[49, 169], [130], [8, 52], [34, 39], [6]]
# [[6], [2, 4], [1, 7], [1], [2]]
# [[73949, 144894], [10], [251353], [122871], [8809]]
# [70.0, 78.83709512164174, 60.0, 40.0, 50.0]
# [0, 102, 0, 0, 0]
# [[455316, 455317], [249798, 340666], [201923, 201924, 201925], [511087], [345917, 387770, 387772, 387773, 389364, 406085]]
# [[18189], [222995], [93192], [1181], [245057]]
# [[265060], [145817, 158981], [11218], [203435], [267307]]
# [[{'review': 'This game is horrible. This game is boring.You can get both endings in under 10 minutes.There is no plot to speak of. An attempt was made, but with less than 100 words of total text, I learned nothing.The puzzles could be completed without the use of a brain.The jump scares, what few there are here, are executed so poorly they border on comically whimsical.Waste of $5 and 10 minutes.', 'author': 'maskedgingerjock', 'recommended': False, 'postedDate': '18 September'}, {'review': "https://youtu.be/dbbmoI0O5UgPretty nice game if you like indie walking simulator games with some jumpscares here and there. It's a bit short for this price, you can finish it within 20 minutes. Other than that it has some puzzles to solve and I like that it has 2 different endings. Please click the link above to see my (no commentary) gameplay.", 'author': 'MisterEcho', 'recommended': True, 'postedDate': '4 September'}, {'review': "Plays fine, looks okay, very limited options, no body, can't jump or crouch, can be finished in about 7 mins with both endings. feels like a demo at best. over priced, under delivered. https://youtu.be/nUwalJOdQdA", 'author': 'Ziggy The Adventurer', 'recommended': None, 'postedDate': '3 September'}], [{'review': 'Warning: Asset Flip!Pet Puzzle is a Unity Asset flip, what Valve calls a "fake game".  The "developer", cBlck, took the Simple match-three animals puzzle Unity Store tutorial/demo/game asset pack from the real developers, CATLOGIC, changed the name, and dumped the result onto Steam.  They\'re attempting to scam people into buying this, so they can get your money for someone else\'s work.cBlck has shown a repeat pattern of unethically dumping other people\'s work onto Steam as a cheap, nasty cash grab. Here\'s some examples so you can see for yourself:  "SnL" = Snakes And Ladders Multiplayer developed by Moe Baker  "Froggo" = Road Crossing Game Template developed by Puppeteer  "Agross" = Agricola Unity developed by Michael Kasprzyk  "Pixelfence" = Pixel Tower Defense Prototype developed by Kirill Nadezhdin  "TacTikk" = Make An Assassins Board Game in Unity developed by Wilmer LinThe products that result from asset flips aren\'t "real" games.  They lack depth and content, because they\'re just simplistic copies of demos or tutorials.  In this case, "Simple match-three animals puzzle" is just a match-3 mobile app template for Unity mobile games, and doesn\'t have any merit as a proper, fully fledged PC game, so a copy+paste of it can\'t be recommended.Asset flips don\'t involve any professional game development.  Sure, sometimes they may change a few cosmetic things, swap out different assets etc, but at heart it\'s functionally identical to the asset they\'re ripping off.Asset flips like this are harmful to the gaming industry and to Steam because they reduce the visibility that sincerely made indie games should have, and make it harder for gamers to find real games from genuine developers.Don\'t reward this morally bankrupt, unethical behaviour from cBlck.', 'author': 'Obey the Fist!', 'recommended': False, 'postedDate': '31 March, 2022\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSteam Key'}], [], [{'review': "I'm gonna be straight up right off the bat, don't buy this game if you aren't prepared for a lot of unfair combat and a fair amount of frustration. This is a modern re-release of a game that comes from the era of old school trial by fire. It doesn't care about being fair, and it doesn't care how many times you lose. If you want to know more, read on.The biggest issue that this game has is unfair enemy behavior. You'll often find yourself spamming punches and kicks, that in any other game would be part of an unbreakable combo chain, but in this game, enemies will nonchalantly start hitting you right through whatever combo you're in the middle of. This is the most common occurrence of the game, and defines most of the combat experience here. What's worse is that all th ...
# ['maskedgingerjock', 'MisterEcho', 'Ziggy The Adventurer', 'Obey the Fist!', 'Sixth']
# ['18 September', '4 September', '3 September', '31 March, 2022\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSteam Key', '21 September, 2022']
# [False, True, None, False, True]
# ['This game is horrible. This game is boring.You can get both endings in under 10 minutes.There is no ...', 'https://youtu.be/dbbmoI0O5UgPretty nice game if you like indie walking simulator games with some jum...', "Plays fine, looks okay, very limited options, no body, can't jump or crouch, can be finished in abou...", 'Warning: Asset Flip!Pet Puzzle is a Unity Asset flip, what Valve calls a "fake game".  The "develope...', "I'm gonna be straight up right off the bat, don't buy this game if you aren't prepared for a lot of ..."]
# [[1002202, 1002203, 1002204, 1002205, 1002206, 1002207], [447897, 447898, 447899, 447900, 447901], [338676, 338677, 338678, 390639, 390640], [1128097, 1128099, 1128104, 1128107, 1128111], [311510, 311511, 311512, 311513, 311514]]
# [[17613, 24620, 36269, 36346, 65827, 76340, 77038, 77597, 111043, 112754], [10605, 56033, 87622, 96217, 101608, 103292, 103369, 111130, 114145, 117533], [3679, 18981, 27378, 38967, 43218, 43488, 43680, 63933, 73042, 76901], [18115, 19222, 25905, 41349, 85804, 87170, 87507, 90788, 90965, 95776], [13189, 25222, 27266, 55282, 75948, 87975, 96217, 106992, 111130, 121217]]
# ['blood-bowl-3-black-orcs-edition', 'shinobi-blade', 'ddrmax2-dance-dance-revolution', 'transformers-prime-the-game', 'dotra']
# [[146969], [3735], [27898], [203628], [128415]]
# [8, 4, 4, 4, 4]
# ['2557720', '1092080', '1667954', '1851020', '2009730']
# ['In the ancient, mysterious world of the Jade Empire, you train under your master’s watchful eye and ...', 'From the frigid climes of Norsca to the arid wastes of the southern Badlands, The Old World echoes t...', 'You live in a peaceful world that has triumphed over a giant alien invasion. To pay off your debts, ...', "You who are unqualified to drink Meng Po's soup, you have been chosen for the game of life. Three wo...", 'Following the end of the Galactic Civil War, the bright lights of The Arena burst into life and offe...']
# ["Fashion is not exactly a priority for Black Orcs… but intimidation, on the other hand, now we're tal...", 'Shinobi Blade is an action-packed game, lets you play the role of a teenage ninja who sneaked out of...', 'The dance floor kicks into overdrive with DDRMAX2 Dance Dance Revolution. It is the latest installme...', 'Shoot bubbles and match colors to pop your way up to victory in this bubble shooting adventure, win ...', 'A missing father, a mysterious murder, paintings depicting missing children. Horror game in which th...']
# [[268435471], [1, 268435460, 268435487, 268435489], [40, 268435463, 268435469, 268435489, 536872611, 536873064, 536875049, 536875350, 536875941, 536876100, 536876101, 536881010, 536884027], [268435465, 268435489], [268435487, 268435488]]
# [[1], [40], [17, 22, 27], [1], [1]]
# [65.0, 70.0, 73.25, 80.66854756082087, 60.0]
# [3, 0, 4, 105, 0]
# [1699266775, 1698219001, 1696215459, 1670993154, 1670992528]
# ['https://www.igdb.com/games/blood-bowl-3-black-orcs-edition', 'https://www.igdb.com/games/shinobi-blade', 'https://www.igdb.com/games/ddrmax2-dance-dance-revolution', 'https://www.igdb.com/games/transformers-prime-the-game', 'https://www.igdb.com/games/dotra']
# [138137, 24115, 139736, 138137, 28856]
# ['Black Orcs Edition', 'Platinum Edition', "Collector's Edition", 'Imperial Nobility Edition', 'Digital Deluxe Edition']
# [[37984], [64610], [28099], [35464], [28553]]
# [[455726], [145653, 145654, 145655, 354472], [445624], [429116], [407422]]

# %% [markdown]
# ## Setup and Dataset Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import json

# Carica il dataset
with open('./../games_dataset_reviews_transformed.json', 'r') as file:
    data = json.load(file)
    
df = pd.json_normalize(data)

# %% [markdown]
# ## Preliminar analysis

# %%
# Visualizza le prime righe del dataset
print(df.head())

# Informazioni sul dataset
print(df.info())

# Statistiche descrittive
print(df.describe())

# Conteggio valori nulli
print(df.isnull().sum())
# Out:
#        id                                       age_ratings artworks  \
# 0  231577  [114607, 114609, 126972, 126973, 126974, 127011]  [96775]
# 1  147666                                    [39395, 54394]  [14195]
# 2   44711                                           [65532]   [9728]
# 3   85450                                           [67799]      NaN
# 4   95080                                               NaN      NaN
#
#    category     cover  created_at  \
# 0         0  280467.0  1673878007
# 1         0  247255.0  1621112209
# 2         0  272120.0  1499434349
# 3         0       NaN  1517405808
# 4         0       NaN  1521818623
#
#                                   external_games  first_release_date  \
# 0  [2639959, 2677882, 2677897, 2677919, 2678595]        1.677110e+09
# 1                                      [2011978]        1.610928e+09
# 2                       [51807, 154169, 1867507]        1.019002e+09
# 3                     [221231, 1748471, 1991656]                 NaN
# 4                                      [1989881]                 NaN
#
#   game_modes       genres  ... rating_count storyline dlcs franchise  \
# 0     [1, 2]         [15]  ...          NaN       NaN  NaN       NaN
# 1        NaN  [4, 31, 33]  ...          NaN       NaN  NaN       NaN
# 2     [1, 2]  [7, 13, 33]  ...          NaN       NaN  NaN       NaN
# 3        NaN          NaN  ...          NaN       NaN  NaN       NaN
# 4        NaN          NaN  ...          NaN       NaN  NaN       NaN
#
#   expanded_games expansions remasters remakes  standalone_expansions forks
# 0            NaN        NaN       NaN     NaN                    NaN   NaN
# 1            NaN        NaN       NaN     NaN                    NaN   NaN
# 2            NaN        NaN       NaN     NaN                    NaN   NaN
# 3            NaN        NaN       NaN     NaN                    NaN   NaN
# 4            NaN        NaN       NaN     NaN                    NaN   NaN
#
# [5 rows x 60 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259290 entries, 0 to 259289
# Data columns (total 60 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       259290 non-null  int64
#  1   age_ratings              58661 non-null   object
#  2   artworks                 100416 non-null  object
#  3   category                 259290 non-null  int64
#  4   cover                    194883 non-null  float64
#  5   created_at               259290 non-null  int64
#  6   external_games           242608 non-null  object
#  7   first_release_date       164967 non-null  float64
#  8   game_modes               139982 non-null  object
#  9   genres                   209590 non-null  object
#  10  name                     259290 non-null  object
#  11  platforms                174749 non-null  object
#  12  release_dates            173643 non-null  object
#  13  screenshots              185718 non-null  object
#  14  similar_games            212521 non-null  object
#  15  slug                     259290 non-null  object
#  16  summary                  220787 non-null  object
#  17  tags                     212539 non-null  object
#  18  updated_at               259290 non-null  int64
#  19  url                      259290 non-null  object
#  20  version_parent           6288 non-null    float64
#  21  version_title            6216 non-null    object
#  22  checksum                 259290 non-null  object
#  23  themes                   139888 non-null  object
#  24  websites                 238616 non-null  object
#  25  language_supports        122872 non-null  object
#  26  alternative_names        58705 non-null   object
#  27  collection               33360 non-null   float64
#  28  follows                  24079 non-null   float64
#  29  franchises               20292 non-null   object
#  30  involved_companies       111122 non-null  object
#  31  keywords                 85179 non-null   object
#  32  multiplayer_modes        11237 non-null   object
#  33  player_perspectives      86053 non-null   object
#  34  videos                   56600 non-null   object
#  35  ports                    3491 non-null    object
#  36  collections              4378 non-null    object
#  37  hypes                    9538 non-null    float64
#  38  status                   16300 non-null   float64
#  39  steam                    88017 non-null   object
#  40  reviews                  88016 non-null   object
#  41  parent_game              32504 non-null   float64
#  42  aggregated_rating        15135 non-null   float64
#  43  aggregated_rating_count  15135 non-null   float64
#  44  bundles                  11739 non-null   object
#  45  game_engines             22514 non-null   object
#  46  total_rating             34899 non-null   float64
#  47  total_rating_count       34899 non-null   float64
#  48  game_localizations       23735 non-null   object
#  49  rating                   29638 non-null   float64
#  50  rating_count             29638 non-null   float64
#  51  storyline                22071 non-null   object
#  52  dlcs                     2701 non-null    object
#  53  franchise                1515 non-null    float64
#  54  expanded_games           1198 non-null    object
#  55  expansions               681 non-null     object
#  56  remasters                867 non-null     object
#  57  remakes                  852 non-null     object
#  58  standalone_expansions    262 non-null     object
#  59  forks                    50 non-null      object
# dtypes: float64(15), int64(4), object(41)
# memory usage: 118.7+ MB
# None
#                   id       category          cover    created_at  \
# count  259290.000000  259290.000000  194883.000000  2.592900e+05
# mean   139540.027926       0.756986  195968.814909  1.582644e+09
# std     80583.295393       2.496363   98195.119340  8.499480e+07
# min         1.000000       0.000000       8.000000  1.297556e+09
# 25%     69860.250000       0.000000  111381.500000  1.506591e+09
# 50%    139613.500000       0.000000  199895.000000  1.602446e+09
# 75%    208938.750000       0.000000  281398.500000  1.657613e+09
# max    279691.000000      14.000000  349278.000000  1.702058e+09
#
#        first_release_date    updated_at  version_parent    collection  \
# count        1.649670e+05  2.592900e+05     6288.000000  33360.000000
# mean         1.356353e+09  1.686677e+09    87128.210878   3501.271823
# std          3.372125e+08  1.413068e+07    76787.695006   2567.381442
# min         -6.943968e+08  1.441385e+09        4.000000      1.000000
# 25%          1.196640e+09  1.681832e+09    11825.500000   1175.750000
# 50%          1.492474e+09  1.690453e+09    77823.000000   3138.000000
# 75%          1.606435e+09  1.694855e+09   140153.250000   5187.000000
# max          1.923955e+09  1.702128e+09   278484.000000   9166.000000
#
#             follows        hypes        status    parent_game  \
# count  24079.000000  9538.000000  16300.000000   32504.000000
# mean      10.399601     3.737891      4.339080   64620.913395
# std       45.081761    17.829781      1.574945   72624.053348
# min        1.000000     1.000000      0.000000       1.000000
# 25%        1.000000     1.000000      4.000000    3277.750000
# 50%        2.000000     1.000000      4.000000   27373.000000
# 75%        5.000000     2.000000      4.000000  119313.000000
# max     1798.000000  1038.000000      8.000000  279404.000000
#
#        aggregated_rating  aggregated_rating_count  total_rating  \
# count       15135.000000             15135.000000  34899.000000
# mean           69.128500                 3.622663     66.545669
# std            16.143250                 4.061751     14.683590
# min             0.000000                 0.000000      0.000000
# 25%            60.000000                 1.000000     59.500000
# 50%            71.666667                 2.000000     70.000000
# 75%            80.000000                 4.000000     77.630457
# max           100.000000                59.000000    100.000000
#
#        total_rating_count        rating  rating_count    franchise
# count        34899.000000  29638.000000  29638.000000  1515.000000
# mean            21.540818     66.671193     23.514542   132.287129
# std            105.874525     14.295509    113.047296   122.077833
# min              0.000000     10.015294      0.000000     1.000000
# 25%              0.000000     59.847596      0.000000    26.000000
# 50%              2.000000     70.000000      2.000000    92.000000
# 75%             10.000000     78.000000     10.000000   222.000000
# max           4161.000000    100.000000   4124.000000   444.000000
# id                              0
# age_ratings                200629
# artworks                   158874
# category                        0
# cover                       64407
# created_at                      0
# external_games              16682
# first_release_date          94323
# game_modes                 119308
# genres                      49700
# name                            0
# platforms                   84541
# release_dates               85647
# screenshots                 73572
# similar_games               46769
# slug                            0
# summary                     38503
# tags                        46751
# updated_at                      0
# url                             0
# version_parent             253002
# version_title              253074
# checksum                        0
# themes                     119402
# websites                    20674
# language_supports          136418
# alternative_names          200585
# collection                 225930
# follows                    235211
# franchises                 238998
# involved_companies         148168
# keywords                   174111
# multiplayer_modes          248053
# player_perspectives        173237
# videos                     202690
# ports                      255799
# collections                254912
# hypes                      249752
# status                     242990
# steam                      171273
# reviews                    171274
# parent_game                226786
# aggregated_rating          244155
# aggregated_rating_count    244155
# bundles                    247551
# game_engines               236776
# total_rating               224391
# total_rating_count         224391
# game_localizations         235555
# rating                     229652
# rating_count               229652
# storyline                  237219
# dlcs                       256589
# franchise                  257775
# expanded_games             258092
# expansions                 258609
# remasters                  258423
# remakes                    258438
# standalone_expansions      259028
# forks                      259240
# dtype: int64

# %% [markdown]
# ## Enetities Analysis
# ### Games

# %%
# Analisi dei generi
genre_counts = df['genres'].explode().value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=genre_counts.index, y=genre_counts.values)
plt.title('Distribuzione dei Generi di Giochi')
plt.xlabel('Genere')
plt.ylabel('Conteggio')
plt.show()

# Analisi delle piattaforme
# Codice simile può essere usato per analizzare le piattaforme
