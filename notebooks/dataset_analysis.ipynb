# %% [markdown]
# # Dataset Preliminary Transformations

# %% [markdown]
# ## ... from Raw to Complete and Definitive

# %% [markdown]
# ### Import Raw Dataset

# %%
import json

# Carica il dataset JSON raw
with open("./../dataset/raw_games_dataset.json", "r") as file:
    json_data_raw = json.load(file)

# %% [markdown]
# ### API request with wrapper

# %%
import os
from dotenv import load_dotenv
from igdb.wrapper import IGDBWrapper

# Carica le variabili d'ambiente
load_dotenv("./.env")

wrapper = IGDBWrapper(
    os.getenv("LSD_CLIENT_ID").strip(), os.getenv("LSD_ACCESS_TOKEN").strip()
)

# %% [markdown]
# ### Raw to Definitive dataset conversion

# %%
# Conversione dataset RAW in dataset definitivo
import json


def transform_json_structure(input_file):
    try:
        # Trasformare il dizionario in una lista di oggetti
        transformed_data = [value for key, value in input_file.items()]
        return transformed_data

    except Exception as e:
        print(f"Si è verificato un errore: {e}")

# Chiamare la funzione per trasformare la struttura del JSON
json_data = transform_json_structure(json_data_raw)

# Salvare il nuovo JSON
#with open("./../dataset/games_dataset_definitive.json", 'w', encoding='utf-8') as file:
#    json.dump(json_data, file, indent=4)

# %% [markdown]
# ### Companies retieval

# %% [markdown]
# 1. Get all of the companies (with the list of the games they developed) from the IGDB API.
# 2. For each company, for each game it developed, access the dataset and add company name and company id as nested object under the key "companies" (a game can have more companies)

# %%
def get_company_for_games(offset):
    """
    Get companies from IGDB API with a certain offset
    """
    try:
        result = wrapper.api_request(
            "companies",
            f"fields id, name, developed; limit 500; sort id asc; offset {offset};",
        ).decode("utf-8")
    except Exception as e:
        print("Errore nella richiesta API:", e)

    return json.loads(result)


group_size = 500
game_ids = [elem["id"] for elem in json_data]
companies = {}
offset = 0
while True:
    companies_buff = get_company_for_games(offset)
    for elem in companies_buff:
        companies[elem["id"]] = elem
    if len(companies_buff) < group_size:
        break
    offset += 500

# salvataggio companies su file
# with open("../dataset/companies.json", "w") as f:
#     f.write(json.dumps(companies, indent=4))

# %%
# eventually retrieve companies from file
with open("../dataset/companies.json", "r") as f:
    companies = json.loads(f.read())

# %%
"""
For each company, we iterate through the "developed" array, which represent the games developed by that company.
We then add a new key "company" to the original dataset's game objects and assign it a list of {company_id, company_name} dictionaries.
"""
for company in companies.values():
    company_obj = {"company_id": company["id"], "company_name": company["name"]}
    if "developed" not in company:
        continue
    for developed_game in company["developed"]:
        stringified_game_id = str(developed_game)
        if stringified_game_id not in json_data_raw:
            continue
        if "companies" in json_data_raw[stringified_game_id]:
            json_data_raw[stringified_game_id]["companies"].append(company_obj)
        else:
            json_data_raw[stringified_game_id]["companies"] = [company_obj]

# salvataggio dataset con companies su file
#with open("./../dataset/raw_dataset_with_companies.json", "w") as f:
#    f.write(json.dumps(json_data_raw, indent=4))

# %% [markdown]
# ### Languages rertieval

# %%
def get_language_support(offset):
    """
    Get language supports from IGDB API with a certain offset
    """
    try:
        result = wrapper.api_request(
            'language_supports', 
            f'fields id, language; limit 500; sort id asc; offset {offset};'
        ).decode('utf-8')
    except Exception as e:
        print("Errore nella richiesta API:", e)

    return json.loads(result)

def get_languages(offset):
    """
    Get languages from IGDB API with a certain offset
    """
    try:
        result = wrapper.api_request(
            'languages', 
            f'fields id, name; limit 500; sort id asc; offset {offset};'
        ).decode('utf-8')
    except Exception as e:
        print("Errore nella richiesta API:", e)

    return json.loads(result)

# %%
group_size = 500
languages_mapping = {}
offset = 0
while True:
    buffer = get_languages(offset)
    for elem in buffer: languages_mapping[elem["id"]] = elem["name"]
    if len(buffer) < group_size: break
    offset += 500

print(f"Fetched {len(languages_mapping)} languages")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 offset = 0
#       4 while True:
# ----> 5     buffer = get_languages(offset)
#       6     for elem in buffer: languages_mapping[elem["id"]] = elem["name"]
#       7     if len(buffer) < group_size: break
#
# NameError: name 'get_languages' is not defined

# %%
import threading
import time
def fetch_language_data(start, group_size, lock):
    while True:
        t = time.time()
        buffer = get_language_support(start)
        elapsed = time.time() - t
        to_sleep = 0.650 - elapsed
        with lock:
            for elem in buffer:
                language_supports_mapping[elem["id"]] = languages_mapping[elem["language"]]
        
        if len(buffer) < group_size:
            break
        if to_sleep > 0: time.sleep(to_sleep)
        start += group_size * 3
        print(start)

group_size = 500
language_supports_mapping = {}
lock = threading.Lock()
threads = []
for i in range(3):
    thread = threading.Thread(target=fetch_language_data, args=(i * group_size, group_size, lock))
    threads.append(thread)
    thread.start()

for thread in threads:
    thread.join()

# salvataggio language_supports_mapping su file
#with open("../dataset/language_supports_mapping.json", "w") as f:
#    f.write(json.dumps(language_supports_mapping, indent = 4))
# Out:
# 2000
# 1500
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 1050011000
#
# 10000
# 12000
# 11500
# 12500
# 13500
# 14000
# 13000
# 14500
# 15000
# 15500
# 16000
# 17000
# 16500
# 17500
# 18500
# 18000
# 20000
# 19000
# 19500
# 21500
# 20500
# 21000
# 23000
# 22500
# 22000
# 24500
# 24000
# 23500
# 26000
# 25500
# 25000
# 27500
# 27000
# 26500
# 29000
# 28500
# 28000
# 30500
# 30000
# 29500
# 32000
# 31500
# 31000
# 33500
# 33000
# 32500
# 35000
# 34500
# 34000
# 36500
# 36000
# 35500
# 38000
# 37500
# 37000
# 39500
# 39000
# 38500
# 41000
# 40500
# 40000
# 42500
# 42000
# 41500
# 44000
# 43500
# 43000
# 45500
# 45000
# 47000
# 44500
# 46500
# 48500
# 46000
# 48000
# 47500
# 50000
# 49500
# 51500
# 49000
# 51000
# 50500
# 53000
# 52500
# 54500
# 52000
# 54000
# 53500
# 56000
# 55500
# 55000
# 57500
# 57000
# 56500
# 59000
# 58500
# 58000
# 60500
# 60000
# 59500
# 61500
# 62000
# 61000
# 63000
# 63500
# 62500
# 64500
# 65000
# 64000
# 66000
# 66500
# 65500
# 67500
# 68000
# 67000
# 69000
# 69500
# 68500
# 70500
# 71000
# 70000
# 72000
# 72500
# 71500
# 73500
# 74000
# 73000
# 75000
# 75500
# 74500
# 76500
# 76000
# 77000
# 78000
# 77500
# 78500
# 79500
# 80000
# 79000
# 81000
# 81500
# 80500
# 82500
# 83000
# 82000
# 84000
# 83500
# 84500
# 85500
# 85000
# 86000
# 87000
# 86500
# 87500
# 88500
# 88000
# 89000
# 90000
# 89500
# 90500
# 91500
# 92000
# 91000
# 93000
# 93500
# 92500
# 94500
# 95000
# 96000
# 94000
# 96500
# 97500
# 95500
# 98000
# 99000
# 97000
# 99500
# 98500
# 100500
# 101000
# 100000
# 102000
# 102500
# 103500
# 101500
# 104000
# 105000
# 103000
# 105500
# 106500
# 104500
# 108000
# 107000
# 106000
# 109500
# 108500
# 107500
# 110000
# 111000
# 111500
# 109000
# 112500
# 113000
# 110500
# 114000
# 114500
# 112000
# 115500
# 116000
# 113500
# 117000
# 115000
# 117500
# 118500
# 116500
# 119000
# 120000
# 120500
# 118000
# 121500
# 122000
# 119500
# 123000
# 123500
# 121000
# 124500
# 122500
# 125000
# 126000
# 124000
# 126500
# 127500
# 128000
# 125500
# 129000
# 129500
# 127000
# 131000
# 130500
# 128500
# 132500
# 132000
# 130000
# 134000
# 133500
# 131500
# 135500
# 135000
# 133000
# 137000
# 136500
# 134500
# 138500
# 138000
# 136000
# 140000
# 137500
# 139500
# 141500
# 141000
# 139000
# 143000
# 142500
# 140500
# 144500
# 144000
# 142000
# 146000
# 143500
# 145500
# 147500
# 147000
# 145000
# 149000
# 146500
# 148500
# 150500
# 150000
# 148000
# 152000
# 151500
# 149500
# 153500
# 153000
# 155000
# 151000
# 154500
# 156500
# 152500
# 156000
# 154000
# 158000
# 157500
# 155500
# 159500
# 159000
# 161000
# 157000
# 160500
# 162500
# 158500
# 162000
# 164000
# 160000
# 163500
# 165500
# 161500
# 165000
# 167000
# 163000
# 166500
# 164500
# 168500
# 168000
# 170000
# 166000
# 169500
# 167500
# 171500
# 171000
# 169000
# 173000
# 172500
# 170500
# 174500
# 174000
# 172000
# 176000
# 175500
# 173500
# 177500
# 177000
# 175000
# 179000
# 178500
# 176500
# 180500
# 180000
# 178000
# 182000
# 181500
# 179500
# 183500
# 183000
# 185000
# 181000
# 184500
# 186500
# 182500
# 186000
# 188000
# 184000
# 187500
# 189500
# 185500
# 189000
# 191000
# 187000
# 190500
# 192500
# 188500
# 192000
# 194000
# 190000
# 193500
# 195500
# 191500
# 195000
# 197000
# 193000
# 196500
# 198500
# 194500
# 198000
# 200000
# 196000
# 199500
# 197500
# 201500
# 201000
# 203000
# 199000
# 204500
# 202500
# 200500
# 204000
# 206000
# 202000
# 203500
# 205500
# 207500
# 209000
# 205000
# 207000
# 206500
# 210500
# 208500
# 208000
# 212000
# 210000
# 213500
# 209500
# 211500
# 215000
# 211000
# 213000
# 216500
# 212500
# 214500
# 218000
# 214000
# 216000
# 215500
# 217500
# 219500
# 217000
# 219000
# 221000
# 218500
# 220500
# 220000
# 222500
# 222000
# 221500
# 224000
# 223000
# 223500
# 225500
# 224500
# 225000
# 227000
# 226500
# 226000
# 228500
# 228000
# 227500
# 229500
# 230000
# 229000
# 231000
# 231500
# 232500
# 230500
# 233000
# 232000
# 234000
# 234500
# 235500
# 233500
# 236000
# 237000
# 237500
# 235000
# 238500
# 239000
# 236500
# 240000
# 240500
# 238000
# 241500
# 242000
# 239500
# 243000
# 241000
# 243500
# 242500
# 244500
# 245000
# 246000
# 244000
# 246500
# 245500
# 247500
# 248000
# 247000
# 249000
# 249500
# 248500
# 250500
# 251000
# 250000
# 252500
# 252000
# 251500
# 254000
# 253500
# 255500
# 255000
# 253000
# 257000
# 256500
# 254500
# 258000
# 258500
# 256000
# 259500
# 257500
# 260000
# 261000
# 259000
# 261500
# 262500
# 260500
# 263000
# 264000
# 262000
# 264500
# 265500
# 263500
# 266000
# 267000
# 265000
# 267500
# 268500
# 266500
# 270000
# 269000
# 268000
# 271500
# 270500
# 269500
# 273000
# 272000
# 271000
# 273500
# 274500
# 272500
# 275000
# 276000
# 274000
# 277500
# 276500
# 275500
# 279000
# 278000
# 277000
# 279500
# 280500
# 278500
# 282000
# 281000
# 280000
# 283500
# 281500
# 282500
# 285000
# 283000
# 284000
# 286500
# 284500
# 285500
# 288000
# 286000
# 287000
# 289500
# 287500
# 288500
# 291000
# 289000
# 290000
# 290500
# 292500
# 292000
# 294000
# 291500
# 293500
# 293000
# 295500
# 295000
# 294500
# 297000
# 296500
# 298500
# 296000
# 297500
# 300000
# 298000
# 301500
# 299000
# 299500
# 303000
# 300500
# 301000
# 304500
# 302000
# 302500
# 306000
# 303500
# 304000
# 307500
# 305000
# 305500
# 309000
# 307000
# 306500
# 310500
# 308500
# 312000
# 308000
# 310000
# 313500
# 309500
# 315000
# 311500
# 311000
# 316500
# 313000
# 312500
# 318000
# 314500
# 314000
# 319500
# 316000
# 315500
# 321000
# 317500
# 317000
# 322500
# 319000
# 318500
# 324000
# 320500
# 320000
# 325500
# 322000
# 321500
# 327000
# 323500
# 323000
# 328500
# 324500
# 325000
# 330000
# 326500
# 326000
# 331500
# 327500
# 328000
# 333000
# 329000
# 329500
# 330500
# 334500
# 331000
# 336000
# 332000
# 333500
# 332500
# 337500
# 334000
# 335000
# 339000
# 335500
# 336500
# 340500
# 338000
# 337000
# 342000
# 338500
# 339500
# 343500
# 341000
# 345000
# 340000
# 346500
# 342500
# 341500
# 348000
# 344000
# 343000
# 349500
# 344500
# 345500
# 347000
# 346000
# 351000
# 348500
# 352500
# 347500
# 349000
# 354000
# 350000
# 350500
# 351500
# 355500
# 352000
# 353000
# 357000
# 353500
# 354500
# 358500
# 355000
# 360000
# 356000
# 356500
# 357500
# 361500
# 359000
# 358000
# 363000
# 360500
# 359500
# 364500
# 362000
# 361000
# 366000
# 363500
# 362500
# 367500
# 365000
# 364000
# 369000
# 366500
# 365500
# 370500
# 368000
# 367000
# 372000
# 369500
# 368500
# 373500
# 371000
# 370000
# 375000
# 372500
# 371500
# 376500
# 374000
# 373000
# 378000
# 379500
# 374500
# 375500
# 381000
# 377000
# 376000
# 382500
# 377500
# 378500
# 384000
# 379000
# 380000
# 385500
# 380500
# 381500
# 387000
# 382000
# 383000
# 388500
# 383500
# 384500
# 385000
# 390000
# 386000
# 386500
# 391500
# 387500
# 388000
# 393000
# 389000
# 389500
# 394500
# 391000
# 390500
# 396000
# 392000
# 392500
# 393500
# 397500
# 394000
# 399000
# 395000
# 395500
# 400500
# 397000
# 396500
# 398500
# 398000
# 402000
# 400000
# 399500
# 403500
# 401500
# 405000
# 401000
# 403000
# 406500
# 402500
# 404500
# 408000
# 404000
# 405500
# 406000
# 409500
# 407000
# 407500
# 411000
# 408500
# 409000
# 412500
# 410500
# 410000
# 414000
# 411500
# 412000
# 415500
# 413000
# 413500
# 417000
# 414500
# 415000
# 418500
# 416000
# 416500
# 420000
# 418000
# 417500
# 419000
# 421500
# 419500
# 420500
# 423000
# 421000
# 424500
# 422000
# 426000
# 422500
# 423500
# 427500
# 424000
# 425500
# 429000
# 425000
# 427000
# 426500
# 430500
# 428000
# 432000
# 428500
# 429500
# 430000
# 433500
# 431500
# 431000
# 435000
# 433000
# 432500
# 436500
# 434500
# 434000
# 438000
# 436000
# 439500
# 435500
# 437500
# 437000
# 441000
# 439000
# 442500
# 438500
# 440500
# 444000
# 442000
# 440000
# 445500
# 443500
# 441500
# 447000
# 445000
# 443000
# 448500
# 446500
# 450000
# 444500
# 448000
# 451500
# 446000
# 449500
# 453000
# 447500
# 451000
# 449000
# 454500
# 452500
# 450500
# 456000
# 452000
# 454000
# 457500
# 455500
# 453500
# 459000
# 457000
# 455000
# 460500
# 456500
# 458500
# 462000
# 460000
# 458000
# 461500
# 459500
# 463000
# 461000
# 464500
# 462500
# 466000
# 464000
# 467500
# 465500
# 469000
# 467000
# 470500
# 468500
# 472000
# 470000
# 473500
# 471500
# 475000
# 473000
# 476500
# 474500
# 478000
# 476000
# 479500
# 477500
# 481000
# 479000
# 480500
# 482500
# 484000
# 482000
# 483500
# 485500
# 485000
# 487000
# 486500
# 488500
# 488000
# 490000
# 489500
# 463500
# 491500
# 491000
# 465000
# 493000
# 492500
# 466500
# 494500
# 468000
# 494000
# 496000
# 495500
# 469500
# 497000
# 497500
# 471000
# 498500
# 499000
# 472500
# 500000
# 500500
# 474000
# 502000
# 501500
# 475500
# 503500
# 503000
# 477000
# 505000
# 504500
# 478500
# 506500
# 506000
# 480000
# 508000
# 507500
# 481500
# 509500
# 509000
# 483000
# 511000
# 510500
# 484500
# 512500
# 486000
# 512000
# 514000
# 487500
# 513500
# 515500
# 489000
# 515000
# 517000
# 490500
# 516500
# 492000
# 518500
# 518000
# 520000
# 493500
# 519500
# 521500
# 495000
# 521000
# 523000
# 496500
# 522500
# 498000
# 524500
# 524000
# 499500
# 526000
# 501000
# 525500
# 527500
# 502500
# 527000
# 529000
# 504000
# 528500
# 530500
# 505500
# 530000
# 507000
# 532000
# 531500
# 533500
# 508500
# 533000
# 510000
# 535000
# 534500
# 511500
# 536500
# 536000
# 513000
# 538000
# 537500514500
#
# 539500
# 539000
# 516000
# 541000
# 540500
# 517500
# 542500
# 542000
# 519000
# 544000
# 543500
# 520500
# 545500
# 545000
# 522000
# 547000
# 546500
# 523500
# 548500
# 525000
# 548000
# 549500
# 550000
# 526500
# 551500
# 551000
# 528000
# 553000
# 529500
# 552500
# 554500
# 554000
# 531000
# 556000
# 555500
# 532500
# 557500
# 534000557000
#
# 559000
# 558500
# 535500
# 560500
# 560000
# 537000
# 562000
# 561500
# 538500
# 563500
# 563000
# 540000
# 565000
# 541500
# 566500
# 564500
# 543000
# 568000
# 566000
# 544500
# 567500
# 569500
# 546000
# 569000
# 571000
# 547500
# 570500
# 572500
# 549000
# 572000
# 574000
# 575500
# 573500
# 550500
# 577000
# 575000
# 578500
# 552000
# 576500
# 580000
# 581500
# 578000
# 553500
# 555000
# 579500
# 583000
# 584500
# 556500
# 581000
# 558000
# 586000
# 582500
# 587500
# 559500
# 584000
# 589000
# 561000
# 585500
# 590500
# 562500
# 587000
# 592000
# 564000
# 588500
# 593500
# 565500
# 590000
# 595000
# 567000
# 596500
# 591500
# 568500
# 593000
# 598000
# 570000
# 594500
# 599500
# 571500
# 596000
# 601000
# 573000
# 597500
# 574500
# 602500
# 599000
# 576000
# 604000
# 600500
# 577500
# 605500
# 602000
# 579000
# 607000
# 603500
# 608500
# 580500
# 605000
# 582000
# 610000
# 606500
# 611500
# 583500
# 608000
# 613000
# 585000
# 609500
# 614500
# 586500
# 611000
# 616000
# 588000
# 612500
# 617500
# 589500
# 614000
# 591000
# 619000
# 615500
# 592500
# 620500
# 617000
# 594000
# 618500
# 622000
# 595500
# 620000
# 623500
# 597000
# 621500
# 625000
# 598500
# 626500
# 623000
# 600000
# 628000
# 624500
# 601500
# 603000
# 629500
# 626000
# 604500
# 627500
# 606000
# 629000
# 631000
# 607500
# 630500
# 632500
# 634000
# 609000
# 635500
# 610500
# 632000
# 633500
# 612000
# 637000
# 635000
# 613500
# 638500
# 615000
# 640000
# 636500
# 616500
# 638000
# 641500
# 639500
# 643000
# 618000
# 644500
# 619500
# 641000
# 646000
# 621000
# 642500
# 622500
# 647500
# 644000
# 624000
# 649000
# 645500
# 625500
# 650500
# 647000
# 627000
# 652000
# 628500
# 648500
# 653500
# 630000
# 650000
# 655000
# 631500
# 651500
# 633000
# 656500
# 634500
# 653000
# 658000
# 654500
# 636000
# 659500
# 656000
# 637500
# 661000
# 657500
# 639000
# 662500
# 659000
# 640500
# 664000
# 660500
# 642000
# 665500
# 662000
# 643500

# %%
# eventually retrieve language_supports_mapping from file
with open("../dataset/language_supports_mapping.json", "r") as f:
    language_supports_mapping = json.loads(f.read())

# %%
print(f"Fetched {len(language_supports_mapping)} language mappings.")
# Out:
# Fetched 824025 language mappings.

# %%
i = 0
for game in json_data_raw:
    if "language_supports" in json_data_raw[game]:
        json_data_raw[game]["language_supports"] = list({language_supports_mapping[x] if x in language_supports_mapping else "English" for x in json_data_raw[game]["language_supports"]})
        #print(i)
        #i+=1

#with open("./../dataset/raw_dataset_with_companies_lang.json","w") as f:
#    f.write(json.dumps(json_data_raw, indent = 4))

# %% [markdown]
# ### Age Ratings Retrieval

# %%
def get_age_rating(offset):
    """
    Get age ratings from IGDB API with a certain offset
    """
    try:
        result = wrapper.api_request(
            'age_ratings', 
            f'fields id, category, rating; limit 500; sort id asc; offset {offset};'
        ).decode('utf-8')
    except Exception as e:
        print("Errore nella richiesta API:", e)

    return json.loads(result)

# %%
group_size = 500
age_ratings_mapping = {}
offset = 0
while True:
    buffer = get_age_rating(offset)
    for elem in buffer: age_ratings_mapping[elem["id"]] = {"age_rating_category": elem["category"], "age_rating_rating": elem["rating"]}
    if len(buffer) < group_size: break
    offset += 500
    print(offset)

print(f"Fetched {len(age_ratings_mapping)} age_ratings")

# salvataggio age_ratings_mapping su file
#with open("../dataset/age_ratings_mapping.json", "w") as f:
#    f.write(json.dumps(age_ratings_mapping, indent = 4))

# %%
# eventually retrieve age_ratings_mapping from file
with open("../dataset/age_ratings_mapping.json", "r") as f:
    age_ratings_mapping = json.loads(f.read())

# %%
for game_id, game in json_data_raw.items():
    if "age_ratings" in game:
        json_data_raw[game_id]["age_ratings"] = [age_ratings_mapping[str(age_rating_id)] for age_rating_id in game["age_ratings"] if str(age_rating_id) in age_ratings_mapping]

#with open("./../dataset/raw_dataset_with_companies_lang_age_rating.json","w") as f:
#    f.write(json.dumps(json_data_raw, indent = 4))

# %% [markdown]
# ### Legend Mapping

# %% [markdown]
# Map categorical fields into the relative values parsed manually from IGDB.

# %%
with open("../dataset/legend.json", "r") as f:
    legend = json.load(f)
for game_id, game in json_data_raw.items():
    for legend_key, legend_mapping in legend.items():
        if legend_key in game:
            if isinstance(game[legend_key], list):
                json_data_raw[game_id][legend_key] = [
                    {
                        legend_key + "_id": str(id),
                        legend_key + "_value": legend_mapping[str(id)],
                    }
                    for id in game[legend_key]
                    if str(id) in legend_mapping
                ]
            else:
                json_data_raw[game_id][legend_key] = {
                    legend_key + "_id": str(game[legend_key]),
                    legend_key + "_value": legend_mapping[str(game[legend_key])],
                }
    if "age_ratings" in game:
        json_data_raw[game_id]["age_ratings"] = [
            {
                "age_rating_category": {
                    "age_rating_category_id": age_rating["age_rating_category"],
                    "age_rating_category_value": legend["age_rating_category"][str(age_rating["age_rating_category"])],
                },
                "age_rating_rating": {
                    "age_rating_rating_id": age_rating["age_rating_rating"],
                    "age_rating_rating_value": legend["age_rating_rating"][str(age_rating["age_rating_rating"])],
                }
            }
            for age_rating in game['age_ratings']
        ]

# %%
print(json.dumps(list(json_data_raw.values())[:25] , indent = 4))
# Out:
# [
#     {
#         "id": 231577,
#         "age_ratings": [
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 2,
#                     "age_rating_category_value": "PEGI"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 4,
#                     "age_rating_rating_value": "Sixteen"
#                 }
#             },
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 1,
#                     "age_rating_category_value": "ESRB"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 10,
#                     "age_rating_rating_value": "T"
#                 }
#             },
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 7,
#                     "age_rating_category_value": "ACB"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 36,
#                     "age_rating_rating_value": "ACB_M"
#                 }
#             },
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 4,
#                     "age_rating_category_value": "USK"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 20,
#                     "age_rating_rating_value": "USK_12"
#                 }
#             },
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 6,
#                     "age_rating_category_value": "CLASS_IND"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 31,
#                     "age_rating_rating_value": "CLASS_IND_Fourteen"
#                 }
#             },
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 5,
#                     "age_rating_category_value": "GRAC"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 25,
#                     "age_rating_rating_value": "GRAC_Fifteen"
#                 }
#             }
#         ],
#         "artworks": [
#             96775
#         ],
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "cover": 280467,
#         "created_at": 1673878007,
#         "external_games": [
#             2639959,
#             2677882,
#             2677897,
#             2677919,
#             2678595
#         ],
#         "first_release_date": 1677110400,
#         "game_modes": [
#             {
#                 "game_modes_id": "1",
#                 "game_modes_value": "Single player"
#             },
#             {
#                 "game_modes_id": "2",
#                 "game_modes_value": "Multiplayer"
#             }
#         ],
#         "genres": [
#             {
#                 "genres_id": "15",
#                 "genres_value": "Strategy"
#             }
#         ],
#         "name": "Blood Bowl 3: Black Orcs Edition",
#         "platforms": [
#             {
#                 "platforms_id": "49",
#                 "platforms_value": "Xbox One"
#             },
#             {
#                 "platforms_id": "169",
#                 "platforms_value": "Xbox Series X|S"
#             }
#         ],
#         "release_dates": [
#             455316,
#             455317
#         ],
#         "screenshots": [
#             1002202,
#             1002203,
#             1002204,
#             1002205,
#             1002206,
#             1002207
#         ],
#         "similar_games": [
#             17613,
#             24620,
#             36269,
#             36346,
#             65827,
#             76340,
#             77038,
#             77597,
#             111043,
#             112754
#         ],
#         "slug": "blood-bowl-3-black-orcs-edition",
#         "summary": "Fashion is not exactly a priority for Black Orcs\u2026 but intimidation, on the other hand, now we're talking! Demand respect with the Black Orcs Edition. It includes customization Items for a Goblin, Troll and Black Orc.",
#         "tags": [
#             268435471
#         ],
#         "updated_at": 1699266775,
#         "url": "https://www.igdb.com/games/blood-bowl-3-black-orcs-edition",
#         "version_parent": 138137,
#         "version_title": "Black Orcs Edition",
#         "checksum": "4e87d634-9146-2025-b09b-9e4ea1e04764"
#     },
#     {
#         "id": 147666,
#         "age_ratings": [
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 1,
#                     "age_rating_category_value": "ESRB"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 9,
#                     "age_rating_rating_value": "E10"
#                 }
#             },
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 2,
#                     "age_rating_category_value": "PEGI"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 2,
#                     "age_rating_rating_value": "Seven"
#                 }
#             }
#         ],
#         "artworks": [
#             14195
#         ],
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "cover": 247255,
#         "created_at": 1621112209,
#         "external_games": [
#             2011978
#         ],
#         "first_release_date": 1610928000,
#         "genres": [
#             {
#                 "genres_id": "4",
#                 "genres_value": "Fighting"
#             },
#             {
#                 "genres_id": "31",
#                 "genres_value": "Adventure"
#             },
#             {
#                 "genres_id": "33",
#                 "genres_value": "Arcade"
#             }
#         ],
#         "name": "Shinobi Blade",
#         "platforms": [
#             {
#                 "platforms_id": "130",
#                 "platforms_value": "Nintendo Switch"
#             }
#         ],
#         "release_dates": [
#             249798,
#             340666
#         ],
#         "screenshots": [
#             447897,
#             447898,
#             447899,
#             447900,
#             447901
#         ],
#         "similar_games": [
#             10605,
#             56033,
#             87622,
#             96217,
#             101608,
#             103292,
#             103369,
#             111130,
#             114145,
#             117533
#         ],
#         "slug": "shinobi-blade",
#         "summary": "Shinobi Blade is an action-packed game, lets you play the role of a teenage ninja who sneaked out of the Dojo, before mastering all the ninja skills. You'll learn what it is to truly be a ninja, be silent, agile and smart to outwit your opponents in 30 gorgeous missions. You need to be agile to avoid meat grinders/poison traps, street smart to solve puzzles/unlock gates. You possess skills such as jump, climb, deadly Katana slashes, lightning-fast shuriken to carve up hordes of gruesome monsters. Upgrade these great skills to overcome all dangers and challenges to complete all the missions. Final showdown with the demon bosses Charybdis, Minotaur and Vampire Kid to become the true master ninja demon slayer!!!",
#         "tags": [
#             1,
#             268435460,
#             268435487,
#             268435489
#         ],
#         "themes": [
#             1
#         ],
#         "updated_at": 1698219001,
#         "url": "https://www.igdb.com/games/shinobi-blade",
#         "websites": [
#             455726
#         ],
#         "checksum": "00e38d21-91cd-3082-4737-7978c44e33e2",
#         "language_supports": [
#             "English"
#         ]
#     },
#     {
#         "id": 44711,
#         "age_ratings": [
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 1,
#                     "age_rating_category_value": "ESRB"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 8,
#                     "age_rating_rating_value": "E"
#                 }
#             }
#         ],
#         "alternative_names": [
#             36941,
#             36942,
#             127468
#         ],
#         "artworks": [
#             9728
#         ],
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "collection": 602,
#         "cover": 272120,
#         "created_at": 1499434349,
#         "external_games": [
#             51807,
#             154169,
#             1867507
#         ],
#         "first_release_date": 1019001600,
#         "follows": 1,
#         "franchises": [
#             1651,
#             3134
#         ],
#         "game_modes": [
#             {
#                 "game_modes_id": "1",
#                 "game_modes_value": "Single player"
#             },
#             {
#                 "game_modes_id": "2",
#                 "game_modes_value": "Multiplayer"
#             }
#         ],
#         "genres": [
#             {
#                 "genres_id": "7",
#                 "genres_value": "Music"
#             },
#             {
#                 "genres_id": "13",
#                 "genres_value": "Simulator"
#             },
#             {
#                 "genres_id": "33",
#                 "genres_value": "Arcade"
#             }
#         ],
#         "involved_companies": [
#             102978,
#             102979
#         ],
#         "keywords": [
#             1699,
#             2152,
#             4137,
#             4438,
#             5029,
#             5188,
#             5189,
#             10098,
#             13115
#         ],
#         "multiplayer_modes": [
#             11174,
#             11175
#         ],
#         "name": "DDRMax2: Dance Dance Revolution",
#         "platforms": [
#             {
#                 "platforms_id": "8",
#                 "platforms_value": "PlayStation 2"
#             },
#             {
#                 "platforms_id": "52",
#                 "platforms_value": "Arcade"
#             }
#         ],
#         "player_perspectives": [
#             6
#         ],
#         "release_dates": [
#             201923,
#             201924,
#             201925
#         ],
#         "screenshots": [
#             338676,
#             338677,
#             338678,
#             390639,
#             390640
#         ],
#         "similar_games": [
#             3679,
#             18981,
#             27378,
#             38967,
#             43218,
#             43488,
#             43680,
#             63933,
#             73042,
#             76901
#         ],
#         "slug": "ddrmax2-dance-dance-revolution",
#         "summary": "The dance floor kicks into overdrive with DDRMAX2 Dance Dance Revolution. It is the latest installment of the highly anticipated DDR series and takes the revolution to the masses! Players can customize their own dance steps and workout in an innovative Exercise Mode. DDR is packed with a smash-hit lineup of all-new exclusive songs, licensed music and dance hits. There are cool contemporary game modes and brand new graphical interfaces featuring music videos that will keep everybody movin' and groovin' to the pulsating beats. DDR Max 2 also includes links to previous games for special features.",
#         "tags": [
#             40,
#             268435463,
#             268435469,
#             268435489,
#             536872611,
#             536873064,
#             536875049,
#             536875350,
#             536875941,
#             536876100,
#             536876101,
#             536881010,
#             536884027
#         ],
#         "themes": [
#             40
#         ],
#         "updated_at": 1696215459,
#         "url": "https://www.igdb.com/games/ddrmax2-dance-dance-revolution",
#         "videos": [
#             37984
#         ],
#         "websites": [
#             145653,
#             145654,
#             145655,
#             354472
#         ],
#         "checksum": "40916ead-d6e4-99f3-ab54-d653605a984b",
#         "ports": [
#             73949,
#             144894
#         ],
#         "collections": [
#             602
#         ],
#         "companies": [
#             {
#                 "company_id": 129,
#                 "company_name": "Konami"
#             },
#             {
#                 "company_id": 159,
#                 "company_name": "Konami Computer Entertainment Tokyo"
#             }
#         ]
#     },
#     {
#         "id": 85450,
#         "age_ratings": [
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 1,
#                     "age_rating_category_value": "ESRB"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 9,
#                     "age_rating_rating_value": "E10"
#                 }
#             }
#         ],
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "created_at": 1517405808,
#         "external_games": [
#             221231,
#             1748471,
#             1991656
#         ],
#         "involved_companies": [
#             85230
#         ],
#         "name": "Transformers Prime: The Game",
#         "slug": "transformers-prime-the-game",
#         "updated_at": 1670993154,
#         "url": "https://www.igdb.com/games/transformers-prime-the-game",
#         "checksum": "489ad4d0-e2f2-09e0-3bae-a76091559c44"
#     },
#     {
#         "id": 95080,
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "created_at": 1521818623,
#         "external_games": [
#             1989881
#         ],
#         "name": "Dotra",
#         "slug": "dotra",
#         "updated_at": 1670992528,
#         "url": "https://www.igdb.com/games/dotra",
#         "websites": [
#             445624
#         ],
#         "checksum": "bc043ffb-ad60-6bd0-801b-55a6141e773c"
#     },
#     {
#         "id": 104748,
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "created_at": 1530519587,
#         "external_games": [
#             1155919,
#             1972586
#         ],
#         "name": "Space station - build your own ISS",
#         "slug": "space-station-build-your-own-iss",
#         "updated_at": 1670986137,
#         "url": "https://www.igdb.com/games/space-station-build-your-own-iss",
#         "websites": [
#             429116
#         ],
#         "checksum": "69cba8e8-24a8-db9c-1970-12e455d00ff9"
#     },
#     {
#         "id": 89616,
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "cover": 192106,
#         "created_at": 1519986874,
#         "external_games": [
#             269608,
#             1949905
#         ],
#         "game_modes": [
#             {
#                 "game_modes_id": "1",
#                 "game_modes_value": "Single player"
#             }
#         ],
#         "genres": [
#             {
#                 "genres_id": "9",
#                 "genres_value": "Puzzle"
#             },
#             {
#                 "genres_id": "33",
#                 "genres_value": "Arcade"
#             }
#         ],
#         "hypes": 1,
#         "involved_companies": [
#             154613
#         ],
#         "name": "Bubble Whirl Shooter",
#         "platforms": [
#             {
#                 "platforms_id": "34",
#                 "platforms_value": "Android"
#             },
#             {
#                 "platforms_id": "39",
#                 "platforms_value": "iOS"
#             }
#         ],
#         "similar_games": [
#             18115,
#             19222,
#             25905,
#             41349,
#             85804,
#             87170,
#             87507,
#             90788,
#             90965,
#             95776
#         ],
#         "slug": "bubble-whirl-shooter",
#         "status": {
#             "status_id": "8",
#             "status_value": "delisted"
#         },
#         "summary": "Shoot bubbles and match colors to pop your way up to victory in this bubble shooting adventure, win magic keys to unlock more secret colorful bubble world, it\u2019s time to enjoy the endless bubble shooting fun!",
#         "tags": [
#             268435465,
#             268435489
#         ],
#         "updated_at": 1678800343,
#         "url": "https://www.igdb.com/games/bubble-whirl-shooter",
#         "websites": [
#             407422
#         ],
#         "checksum": "970708ae-528c-7915-8f18-8786a4120376",
#         "companies": [
#             {
#                 "company_id": 38839,
#                 "company_name": "Meng Li"
#             }
#         ]
#     },
#     {
#         "id": 91579,
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "created_at": 1521138594,
#         "external_games": [
#             128240,
#             1189096
#         ],
#         "name": "Racing Live",
#         "slug": "racing-live",
#         "updated_at": 1670942773,
#         "url": "https://www.igdb.com/games/racing-live",
#         "websites": [
#             346516
#         ],
#         "checksum": "3bf799f5-07cd-c4af-a786-f50dbc8d9cdf"
#     },
#     {
#         "id": 263822,
#         "artworks": [
#             115992
#         ],
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "cover": 326638,
#         "created_at": 1693294006,
#         "external_games": [
#             2736789,
#             2736925
#         ],
#         "game_modes": [
#             {
#                 "game_modes_id": "1",
#                 "game_modes_value": "Single player"
#             }
#         ],
#         "genres": [
#             {
#                 "genres_id": "31",
#                 "genres_value": "Adventure"
#             },
#             {
#                 "genres_id": "32",
#                 "genres_value": "Indie"
#             }
#         ],
#         "name": "All Alone",
#         "screenshots": [
#             1128097,
#             1128099,
#             1128104,
#             1128107,
#             1128111
#         ],
#         "similar_games": [
#             13189,
#             25222,
#             27266,
#             55282,
#             75948,
#             87975,
#             96217,
#             106992,
#             111130,
#             121217
#         ],
#         "slug": "all-alone",
#         "summary": "A missing father, a mysterious murder, paintings depicting missing children. Horror game in which the protagonist, who has lost his memory, is forced to get to a horrific truth. Who in the world are you?",
#         "tags": [
#             268435487,
#             268435488
#         ],
#         "updated_at": 1693399906,
#         "url": "https://www.igdb.com/games/all-alone",
#         "websites": [
#             577548
#         ],
#         "checksum": "4961b1b3-4453-5b62-e96b-4ccc836524f3",
#         "language_supports": [
#             "English"
#         ],
#         "steam": "2557720",
#         "reviews": [
#             {
#                 "review": "This game is horrible. This game is boring.You can get both endings in under 10 minutes.There is no plot to speak of. An attempt was made, but with less than 100 words of total text, I learned nothing.The puzzles could be completed without the use of a brain.The jump scares, what few there are here, are executed so poorly they border on comically whimsical.Waste of $5 and 10 minutes.",
#                 "author": "maskedgingerjock",
#                 "recommended": false,
#                 "postedDate": "18 September"
#             },
#             {
#                 "review": "https://youtu.be/dbbmoI0O5UgPretty nice game if you like indie walking simulator games with some jumpscares here and there. It's a bit short for this price, you can finish it within 20 minutes. Other than that it has some puzzles to solve and I like that it has 2 different endings. Please click the link above to see my (no commentary) gameplay.",
#                 "author": "MisterEcho",
#                 "recommended": true,
#                 "postedDate": "4 September"
#             },
#             {
#                 "review": "Plays fine, looks okay, very limited options, no body, can't jump or crouch, can be finished in about 7 mins with both endings. feels like a demo at best. over priced, under delivered. https://youtu.be/nUwalJOdQdA",
#                 "author": "Ziggy The Adventurer",
#                 "recommended": null,
#                 "postedDate": "3 September"
#             }
#         ]
#     },
#     {
#         "id": 124961,
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "created_at": 1571616000,
#         "name": "Railroad Tycoon 2: Platinum Edition",
#         "slug": "railroad-tycoon-2-platinum-edition",
#         "updated_at": 1571616000,
#         "url": "https://www.igdb.com/games/railroad-tycoon-2-platinum-edition",
#         "version_parent": 24115,
#         "version_title": "Platinum Edition",
#         "websites": [
#             121131
#         ],
#         "checksum": "c405b7c1-7d15-9e53-c0eb-c3ad3f4af32a"
#     },
#     {
#         "id": 119025,
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "created_at": 1558701524,
#         "external_games": [
#             1723803,
#             1957721
#         ],
#         "first_release_date": 1559952000,
#         "game_modes": [
#             {
#                 "game_modes_id": "1",
#                 "game_modes_value": "Single player"
#             }
#         ],
#         "genres": [
#             {
#                 "genres_id": "13",
#                 "genres_value": "Simulator"
#             }
#         ],
#         "involved_companies": [
#             229692,
#             229693
#         ],
#         "keywords": [
#             101
#         ],
#         "name": "Pet Puzzle",
#         "platforms": [
#             {
#                 "platforms_id": "6",
#                 "platforms_value": "PC (Microsoft Windows)"
#             }
#         ],
#         "release_dates": [
#             511087
#         ],
#         "screenshots": [
#             311510,
#             311511,
#             311512,
#             311513,
#             311514
#         ],
#         "similar_games": [
#             17613,
#             24620,
#             36346,
#             65827,
#             76340,
#             87485,
#             100794,
#             101573,
#             105264,
#             112754
#         ],
#         "slug": "pet-puzzle",
#         "summary": "Pet Puzzle is a relaxing and leisurely three-in-a-row game.",
#         "tags": [
#             268435469
#         ],
#         "updated_at": 1693604655,
#         "url": "https://www.igdb.com/games/pet-puzzle",
#         "websites": [
#             109221,
#             414926
#         ],
#         "checksum": "f8d47ec5-e7f3-a792-e2d8-09d25e05f609",
#         "language_supports": [
#             "English"
#         ],
#         "steam": "1092080",
#         "reviews": [
#             {
#                 "review": "Warning: Asset Flip!Pet Puzzle is a Unity Asset flip, what Valve calls a \"fake game\".  The \"developer\", cBlck, took the Simple match-three animals puzzle Unity Store tutorial/demo/game asset pack from the real developers, CATLOGIC, changed the name, and dumped the result onto Steam.  They're attempting to scam people into buying this, so they can get your money for someone else's work.cBlck has shown a repeat pattern of unethically dumping other people's work onto Steam as a cheap, nasty cash grab. Here's some examples so you can see for yourself:  \"SnL\" = Snakes And Ladders Multiplayer developed by Moe Baker  \"Froggo\" = Road Crossing Game Template developed by Puppeteer  \"Agross\" = Agricola Unity developed by Michael Kasprzyk  \"Pixelfence\" = Pixel Tower Defense Prototype developed by Kirill Nadezhdin  \"TacTikk\" = Make An Assassins Board Game in Unity developed by Wilmer LinThe products that result from asset flips aren't \"real\" games.  They lack depth and content, because they're just simplistic copies of demos or tutorials.  In this case, \"Simple match-three animals puzzle\" is just a match-3 mobile app template for Unity mobile games, and doesn't have any merit as a proper, fully fledged PC game, so a copy+paste of it can't be recommended.Asset flips don't involve any professional game development.  Sure, sometimes they may change a few cosmetic things, swap out different assets etc, but at heart it's functionally identical to the asset they're ripping off.Asset flips like this are harmful to the gaming industry and to Steam because they reduce the visibility that sincerely made indie games should have, and make it harder for gamers to find real games from genuine developers.Don't reward this morally bankrupt, unethical behaviour from cBlck.",
#                 "author": "Obey the Fist!",
#                 "recommended": false,
#                 "postedDate": "31 March, 2022\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSteam Key"
#             }
#         ],
#         "companies": [
#             {
#                 "company_id": 43516,
#                 "company_name": "cBlck"
#             }
#         ]
#     },
#     {
#         "id": 71632,
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "collection": 2449,
#         "cover": 42594,
#         "created_at": 1506675676,
#         "external_games": [
#             152876,
#             1868210
#         ],
#         "franchises": [
#             872,
#             874
#         ],
#         "genres": [
#             {
#                 "genres_id": "15",
#                 "genres_value": "Strategy"
#             }
#         ],
#         "keywords": [
#             78,
#             394,
#             960,
#             1033,
#             2458
#         ],
#         "name": "Ganbare Goemon: Mononoke Sugoroku",
#         "similar_games": [
#             6985,
#             18623,
#             19164,
#             19404,
#             23345,
#             35371,
#             36553,
#             55029,
#             79134,
#             119156
#         ],
#         "slug": "ganbare-goemon-mononoke-sugoroku",
#         "summary": "A compilation of the first two Super Famicom Goemon games.",
#         "tags": [
#             17,
#             22,
#             27,
#             268435471,
#             536870990,
#             536871306,
#             536871872,
#             536871945,
#             536873370
#         ],
#         "themes": [
#             17,
#             22,
#             27
#         ],
#         "updated_at": 1686031007,
#         "url": "https://www.igdb.com/games/ganbare-goemon-mononoke-sugoroku",
#         "websites": [
#             355140
#         ],
#         "checksum": "f5349ec4-124d-0812-e7cb-704a2d84dd17"
#     },
#     {
#         "id": 160939,
#         "category": {
#             "category_id": "1",
#             "category_value": "dlc_addon"
#         },
#         "created_at": 1627934426,
#         "external_games": [
#             2077605
#         ],
#         "genres": [
#             {
#                 "genres_id": "32",
#                 "genres_value": "Indie"
#             }
#         ],
#         "name": "Tiger Tank 59 I: A-Gun MP095",
#         "parent_game": 110980,
#         "screenshots": [
#             562356,
#             562358,
#             562365,
#             562372,
#             562377
#         ],
#         "similar_games": [
#             32902,
#             37419,
#             40524,
#             76263,
#             96217,
#             105233,
#             106987,
#             111130,
#             113895,
#             119121
#         ],
#         "slug": "tiger-tank-59-i-a-gun-mp095",
#         "summary": "\"Tiger Tank 59\" is a top-down shooting game. Players need to control their tanks, through the enemy lines, break the enemy base, or defeat the enemy tanks. This DLC contains the Map No.491-495.",
#         "tags": [
#             1,
#             268435488
#         ],
#         "themes": [
#             1
#         ],
#         "updated_at": 1685761108,
#         "url": "https://www.igdb.com/games/tiger-tank-59-i-a-gun-mp095",
#         "websites": [
#             207860,
#             207861
#         ],
#         "checksum": "6bc319a3-3d9c-8308-576b-c102901b8b65",
#         "language_supports": [
#             "English"
#         ],
#         "steam": "1667954",
#         "reviews": []
#     },
#     {
#         "id": 130740,
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "created_at": 1582360476,
#         "external_games": [
#             1617427,
#             1911867
#         ],
#         "name": "Deathmatch Club",
#         "slug": "deathmatch-club",
#         "updated_at": 1670968762,
#         "url": "https://www.igdb.com/games/deathmatch-club",
#         "websites": [
#             386427
#         ],
#         "checksum": "2504a9b2-c115-0252-9f5a-850ff9924a4f"
#     },
#     {
#         "id": 137195,
#         "age_ratings": [
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 6,
#                     "age_rating_category_value": "CLASS_IND"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 29,
#                     "age_rating_rating_value": "CLASS_IND_Ten"
#                 }
#             },
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 2,
#                     "age_rating_category_value": "PEGI"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 3,
#                     "age_rating_rating_value": "Twelve"
#                 }
#             },
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 1,
#                     "age_rating_category_value": "ESRB"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 9,
#                     "age_rating_rating_value": "E10"
#                 }
#             },
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 5,
#                     "age_rating_category_value": "GRAC"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 24,
#                     "age_rating_rating_value": "GRAC_Twelve"
#                 }
#             },
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 7,
#                     "age_rating_category_value": "ACB"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 35,
#                     "age_rating_rating_value": "ACB_PG"
#                 }
#             },
#             {
#                 "age_rating_category": {
#                     "age_rating_category_id": 4,
#                     "age_rating_category_value": "USK"
#                 },
#                 "age_rating_rating": {
#                     "age_rating_rating_id": 20,
#                     "age_rating_rating_value": "USK_12"
#                 }
#             }
#         ],
#         "aggregated_rating": 65.0,
#         "aggregated_rating_count": 3,
#         "alternative_names": [
#             65648,
#             105850,
#             117666
#         ],
#         "artworks": [
#             11731,
#             68424
#         ],
#         "bundles": [
#             263897
#         ],
#         "category": {
#             "category_id": "9",
#             "category_value": "remaster"
#         },
#         "collection": 7103,
#         "cover": 232868,
#         "created_at": 1598520979,
#         "external_games": [
#             1883673,
#             2440052,
#             2533073,
#             2568678,
#             2593265,
#             2593515,
#             2593572,
#             2593860,
#             2658599
#         ],
#         "first_release_date": 1644796800,
#         "follows": 1,
#         "franchises": [
#             3390
#         ],
#         "game_engines": [
#             1543
#         ],
#         "game_modes": [
#             {
#                 "game_modes_id": "1",
#                 "game_modes_value": "Single player"
#             },
#             {
#                 "game_modes_id": "2",
#                 "game_modes_value": "Multiplayer"
#             }
#         ],
#         "genres": [
#             {
#                 "genres_id": "4",
#                 "genres_value": "Fighting"
#             },
#             {
#                 "genres_id": "25",
#                 "genres_value": "Hack and slash/Beat 'em up"
#             },
#             {
#                 "genres_id": "31",
#                 "genres_value": "Adventure"
#             },
#             {
#                 "genres_id": "33",
#                 "genres_value": "Arcade"
#             }
#         ],
#         "involved_companies": [
#             194995,
#             194996
#         ],
#         "name": "River City Girls Zero",
#         "parent_game": 46584,
#         "platforms": [
#             {
#                 "platforms_id": "6",
#                 "platforms_value": "PC (Microsoft Windows)"
#             },
#             {
#                 "platforms_id": "48",
#                 "platforms_value": "PlayStation 4"
#             },
#             {
#                 "platforms_id": "49",
#                 "platforms_value": "Xbox One"
#             },
#             {
#                 "platforms_id": "130",
#                 "platforms_value": "Nintendo Switch"
#             },
#             {
#                 "platforms_id": "167",
#                 "platforms_value": "PlayStation 5"
#             },
#             {
#                 "platforms_id": "169",
#                 "platforms_value": "Xbox Series X|S"
#             }
#         ],
#         "player_perspectives": [
#             2,
#             4
#         ],
#         "release_dates": [
#             345917,
#             387770,
#             387772,
#             387773,
#             389364,
#             406085
#         ],
#         "screenshots": [
#             740764,
#             740765,
#             740766,
#             740767,
#             740768
#         ],
#         "similar_games": [
#             76253,
#             87622,
#             90011,
#             101608,
#             103168,
#             103369,
#             111130,
#             114145,
#             115283,
#             117533
#         ],
#         "slug": "river-city-girls-zero",
#         "summary": "River City Girls Zero lets you experience the first time that Misako and Kyoko teamed up with Kunio and Riki to take to the streets in hard-hitting, curb-stomping action. While the graphics, music, and gameplay all remain true to the classic 16-bit Super Famicom release, this version marks the first time the 1994 game will be localized for the West. A new opening cinematic, new manga cutscenes, and new theme song by River City Girls composer Megan McDuffee have been added as well. Set out solo or team up with a friend in local co-op and discover how the River City Girls story began!",
#         "tags": [
#             1,
#             268435460,
#             268435481,
#             268435487,
#             268435489
#         ],
#         "themes": [
#             1
#         ],
#         "total_rating": 65.0,
#         "total_rating_count": 3,
#         "updated_at": 1701460057,
#         "url": "https://www.igdb.com/games/river-city-girls-zero",
#         "videos": [
#             64610
#         ],
#         "websites": [
#             186924,
#             186925,
#             186929,
#             265585,
#             283677,
#             369475
#         ],
#         "checksum": "170d53e6-afa5-aac7-b6c4-31a00218ebda",
#         "language_supports": [
#             "English"
#         ],
#         "game_localizations": [
#             2026,
#             13450
#         ],
#         "steam": "1851020",
#         "reviews": [
#             {
#                 "review": "I'm gonna be straight up right off the bat, don't buy this game if you aren't prepared for a lot of unfair combat and a fair amount of frustration. This is a modern re-release of a game that comes from the era of old school trial by fire. It doesn't care about being fair, and it doesn't care how many times you lose. If you want to know more, read on.The biggest issue that this game has is unfair enemy behavior. You'll often find yourself spamming punches and kicks, that in any other game would be part of an unbreakable combo chain, but in this game, enemies will nonchalantly start hitting you right through whatever combo you're in the middle of. This is the most common occurrence of the game, and defines most of the combat experience here. What's worse is that all the enemies in the game are tanks, requiring more damage than what feels reasonable to take even just one of them down. You're going to be frequently outnumbered, taking tons of unfair damage, which is going to compel most players to start playing in an exploitative fashion. You do have infinite lives, but not every checkpoint is forgiving, so if you aren't ready to deal with that, this isn't for you.You play as all four River City characters in this game, swapping them out on the fly, which should have been cool, but it kinda isn't. I say that because although you can swap them all out on the fly, they each have their own individual health bars, which sounds okay, until you discover that if one of them dies, they all die. The game basically makes you flirt with death, swapping out characters before they die, which essentially equals the player having less health. This could have been a reasonable gameplay mechanic if all four of the characters offered a different playstyle from one another, but they don't. The boys play identically to one another; the girls play identically to one another; and the boys and girls differ ever so slightly from one another. In theory, this means you actually would have been better off just playing as a single character with an extended health bar, equal to all four.Am I being way too harsh here? Kinda. This is a really old game, and the standards were different back then. If I'm being honest with myself, if I had this game as a kid, I actually think I would have loved it. It's an unfair game, no doubt, but if you grew up in the 90's, that's nothing new, and being unfair certainly didn't stop these kinds of games from being a good time (not always). The combat is still fun enough, the environments are interesting, and the game has a decent amount of pre-fight dialogue before boss encounters, giving every fight context and purpose (which wasn't very common for beat'em'up games in the era this was made in). Co-op is probably not a bad time with this one either, though I haven't tried that to speak too much on it, so I won't.Given that this is 2022 though, some folks might be compelled to judge this game off the backs of more recent games like the original River City Girls, Mother Russia Bleeds, and Streets of Rage 4. Does this have anywhere near the same modern day sensibilities that those games have? No. Duh, right? But still, just as a fair warning to anyone born after the year 2000, I know that your first experience with River City games is likely 2019's River City Girls. Just know that this is a vastly different beast from that game. Don't expect ANY of the humor of that game here, nor a catchy soundtrack that will make you want to own the songs (aside from the awesome intro song which was added in just for this release), nor any of the RPG elements. THIS-IS-DIFFERENT. The game does include a tailored intro that features the girls in their modern day forms, and it's pretty cool, but that's about all that this game has in connection with the previous one. The playable portion of this will punish you, as most of the games from its time did.P.S. This game dawns the name River City Girls, but that's just for bran ...
#                 "author": "Sixth",
#                 "recommended": true,
#                 "postedDate": "21 September, 2022"
#             },
#             {
#                 "review": "A modern day re-release of the last entry for the Nekketsu Koha series in the Kunio-kun franchise placed into the River City Girls spinoff series. This release was a split project between WayForward who handled all of the translations & newly added visuals wrapped around the game with Limited Run Games handling the original game itself. WayForward chose to take this project on as a way to serve as an origin story for Misako & Kyoko's playable debuts in the franchise with many of the events & characters in this game to be referenced in the upcoming River City Girls 2.Without any source code being available for the project, emulation was used on the Carbon engine which was originally made for Shantae GBC's re-release on the Switch. Nothing was changed about the original game apart from being available in other languages so any issues from then remain present here. The emulator runs fine, though backing in & out of a game may sometimes cause game audio to cut out entirely or other similar issues at the time of writing.From the gameplay side of things this plays well enough and should feel pretty familiar to those who've played the original arcade game or Technos' other franchise Double Dragon. Playing this present day the controls can feel stiff compared to the Downtown Nekketsu beat em' up games seen on the NES and especially to those who might be coming straight out of River City Girls' modern approach. You're using your punch & kicks throughout with the boys being able to perform grabs and the girls being able to move & attack faster. The game is played in a stage-by-stage linear fashion and certainly doesn't overstay it's welcome in the total length with you being able to clear the whole thing in a couple of hours dependant on how many times you die throughout.What I'd say to be the real meat & potatoes would have to be the story. The Koha series of Kunio games were all made with relatively darker & serious themes in mind in comparison to the others and this is no exception. WayForward provides two options for the script with those either being the original 1994 script or a flavoured version edited to sound more like the characters' River City Girls counterparts. Both scripts provide a good experience throughout!The biggest flaw the PC version has is that there's no sort of settings menu at all. Your volume, window size, full screen, or keyboard controls cannot be changed at all or must be manually done. If all of this is not an issue or you're playing on a controller then in it's current state I can suggest the PC version. If any of these are an issue but you'd still like to purchase a copy of the game instead of resorting to playing the old fan translation then I'd recommend any of the console releases. The game itself is more than fine but the PC version in specific needs some more work done.",
#                 "author": "mr burns",
#                 "recommended": true,
#                 "postedDate": "23 September, 2022"
#             },
#             {
#                 "review": "First off: There are 2 possible translations possible in English. An original adaptation to make it flow better with river city girls 1 and a new one which is a close translation to the Japanese. The devs listened to feedback and provided extra options which is to be commended. What is this game? This is a very old school brawler. This was a \"graphical update\" from the nes sprites of the original and I the only game in the \"kunio\" or \"river city ransom\" series that seems to use these sprites. There are also no rpg elements in this one. You can't pop in a shop to eat, buy skill books or anything like that. It's pure action. True to form, the Japanese only uses hiragana and kana for text and it is hard to read due to the low resolution.The story is a bigger deal and a bit the beginning is a bit darker than the typical kunio game. The title is also a bit misleading since the girls are playable, but the main stars are kunio and riki. The Japanese title makes that a bit more clear. You eventually have 4 characters, which can be shared with another player (regardless if they own the game or not) or you can use all 4 for yourself and switch them out. In single player at least, if anyone of them get knocked out, you lose. You need to switch before they get KOed. What is a bit unusual for this game is that the enemies have more combo priority than you do. Most brawlers or fighting games have a kind of hit stun after you hit someone or invincibility frames. You don't get that here; your combos will be broken by the guy you are wailing on, if they feel like it. That doesn't work both ways though, you can't really break out of a combo yourself. Think of it this way: in case of a tie, the player loses. In modern games it is the opposite. This is the source of the perceived difficulty of the game. Therefore, I found that the best way to fight is to knock them down with one hit. The good ol jump kick them to death technique from back in the day is back. Some reviews commented that all 4 characters are essentially the same and just a lifebar. This is incorrect and it only seems that way at the beginning: the special moves are different and the girls slap instead of punch which seems slightly easier to finish combos with than punches. I am not sure on damage numbers but according to a guide a steam, not all attacks do the same amount of damage.The remastering of this game adds a link to the newest river city girl through an intro comic and opening. I like how the song sounds slightly distorted like it was recorded in the 80s. You can also add some filters but I didn't see a huge difference other than the CRT filter. Another addition is the use of saving. The old game used a password system. You input a password and it brings you to that stage. You can use either. This allows you to skip parts of the game if you like. The game isn't terribly long but you may prefer some stages over others when replaying. For more Japanese games on pc check out https://store.steampowered.com/curator/33962119-Japanese-Games-On-PC/",
#                 "author": "Delicious Banchou",
#                 "recommended": true,
#                 "postedDate": "1 October, 2022\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSteam Key"
#             },
#             {
#                 "review": "Still a great classic beat em up, no doubt about it. 4 characters, variety in levels, funny story.The only new addition to the original Shin nekketsu k\u014dha Kunio-tachi no banka game is the fully voiced intro & outro.Sadly it doesn't have online coop other than through Steam remote-play.",
#                 "author": "Elf Kaicho",
#                 "recommended": true,
#                 "postedDate": "27 January\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSteam Key"
#             },
#             {
#                 "review": "It's an old game, don't expect it to hold your hand. It lets you beat em up alright, but it is a little stiff in comparison to recent releases. Loved it's soundtrack and tone,",
#                 "author": "REUMOSAN",
#                 "recommended": true,
#                 "postedDate": "18 December, 2022"
#             },
#             {
#                 "review": "I feel this game is more charming than River City Girls 1&2. Maybe because of the tone of story. Maybe because of the hardcore& challenge fight.",
#                 "author": "SuperKeyboardFighter",
#                 "recommended": true,
#                 "postedDate": "17 December, 2022"
#             },
#             {
#                 "review": "A nice piece of gaming history but not for everyone.If you like old-school Beat'em ups or are a fan of River City Girls you're probably gonna like this game if only to see the first apperance of Misako and Kyoko.I also think that it's important that older games are accessible to a main-stream audience without having to resort to piracy or spending a ridiculous amount of money.",
#                 "author": "Rei",
#                 "recommended": true,
#                 "postedDate": "19 January"
#             },
#             {
# ...
#                 "author": "elena_tapean",
#                 "recommended": true,
#                 "postedDate": "30 May, 2021"
#             },
#             {
#                 "review": "I purchased this game on steam while on sale.  It is a good game with a bonus chapter.  There is no map but has a strategy guide and hint button.  Puzzles are relatively simple.  I had no issues with the game and would recommend it.",
#                 "author": "cjnew",
#                 "recommended": true,
#                 "postedDate": "16 April, 2020"
#             },
#             {
#                 "review": "I highly recommend this game. 5 stars.",
#                 "author": "Aaron",
#                 "recommended": true,
#                 "postedDate": "19 June, 2022"
#             },
#             {
#                 "review": "Just like most mystery games along with hidden item games.  Visuals feel comforting to look at if you are into older looking games.  Feels somewhat nostalgic.  Also a fun game to play while under the influence :) The story is okay and the mystery is fun.  The music is also very nice. Its kind of like: Kronville - Stolen dreams.",
#                 "author": "Sammishka",
#                 "recommended": true,
#                 "postedDate": "20 August, 2021"
#             }
#         ],
#         "companies": [
#             {
#                 "company_id": 19036,
#                 "company_name": "ERS G Studios"
#             }
#         ]
#     },
#     {
#         "id": 30132,
#         "artworks": [
#             32672
#         ],
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "cover": 170169,
#         "created_at": 1495375281,
#         "external_games": [
#             1655,
#             1991882
#         ],
#         "first_release_date": 1600992000,
#         "follows": 1,
#         "game_modes": [
#             {
#                 "game_modes_id": "1",
#                 "game_modes_value": "Single player"
#             }
#         ],
#         "genres": [
#             {
#                 "genres_id": "12",
#                 "genres_value": "Role-playing (RPG)"
#             },
#             {
#                 "genres_id": "15",
#                 "genres_value": "Strategy"
#             },
#             {
#                 "genres_id": "32",
#                 "genres_value": "Indie"
#             }
#         ],
#         "involved_companies": [
#             138839
#         ],
#         "name": "Wizards and Warlords",
#         "platforms": [
#             {
#                 "platforms_id": "3",
#                 "platforms_value": "Linux"
#             },
#             {
#                 "platforms_id": "6",
#                 "platforms_value": "PC (Microsoft Windows)"
#             },
#             {
#                 "platforms_id": "14",
#                 "platforms_value": "Mac"
#             }
#         ],
#         "rating": 70.0,
#         "rating_count": 0,
#         "release_dates": [
#             271629,
#             271630,
#             271631,
#             289716,
#             289717,
#             289718
#         ],
#         "screenshots": [
#             489141,
#             489142,
#             489143,
#             489144,
#             489145,
#             489146,
#             489147,
#             489148
#         ],
#         "similar_games": [
#             19404,
#             25311,
#             28182,
#             35994,
#             36269,
#             65827,
#             102420,
#             109339,
#             113402,
#             116992
#         ],
#         "slug": "wizards-and-warlords",
#         "summary": "Wizards and Warlords is an indie turn-based strategy game, where you play in a randomly generated fantasy world, contending with rival wizards, warlords, roaming marauders and hidden ancient evils. Create a customized sovereign or choose from one of many predefined templates.",
#         "tags": [
#             268435468,
#             268435471,
#             268435488
#         ],
#         "total_rating": 70.0,
#         "total_rating_count": 0,
#         "updated_at": 1686845452,
#         "url": "https://www.igdb.com/games/wizards-and-warlords",
#         "websites": [
#             28091,
#             28092,
#             447530
#         ],
#         "checksum": "cfdf5a71-6f46-5512-b39a-10f148963a46",
#         "language_supports": [
#             "English"
#         ],
#         "companies": [
#             {
#                 "company_id": 35057,
#                 "company_name": "Valravn Games"
#             }
#         ]
#     },
#     {
#         "id": 176242,
#         "artworks": [
#             54799
#         ],
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "created_at": 1634290363,
#         "external_games": [
#             2134008,
#             2134437
#         ],
#         "name": "This hole in my chest",
#         "screenshots": [
#             662953
#         ],
#         "slug": "this-hole-in-my-chest",
#         "summary": "A game about feeling empty",
#         "updated_at": 1671002976,
#         "url": "https://www.igdb.com/games/this-hole-in-my-chest",
#         "websites": [
#             235737,
#             472880
#         ],
#         "checksum": "f3d3f9f3-2ed2-06f3-ecf3-ffd1846f6fba"
#     },
#     {
#         "id": 85137,
#         "artworks": [
#             1843
#         ],
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "created_at": 1517394982,
#         "external_games": [
#             217493,
#             1946846
#         ],
#         "first_release_date": 1253836800,
#         "involved_companies": [
#             237438
#         ],
#         "name": "Family Trainer: Extreme Challenge",
#         "platforms": [
#             {
#                 "platforms_id": "5",
#                 "platforms_value": "Wii"
#             }
#         ],
#         "release_dates": [
#             139330
#         ],
#         "screenshots": [
#             158447,
#             158448,
#             158449,
#             158450,
#             158451,
#             158452,
#             158453,
#             158454,
#             158455,
#             158456,
#             158457,
#             158458
#         ],
#         "slug": "family-trainer-extreme-challenge",
#         "summary": "Family Trainer: Extreme Challenge is the follow up to the successful Family Trainer game/mat bundle.",
#         "updated_at": 1698789284,
#         "url": "https://www.igdb.com/games/family-trainer-extreme-challenge",
#         "websites": [
#             404491
#         ],
#         "checksum": "cd048513-e35f-2730-ef30-360c08371358"
#     },
#     {
#         "id": 94975,
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "created_at": 1521565054,
#         "external_games": [
#             328985,
#             1954152
#         ],
#         "name": "Wubble Bubbles",
#         "slug": "wubble-bubbles",
#         "updated_at": 1670979157,
#         "url": "https://www.igdb.com/games/wubble-bubbles",
#         "websites": [
#             411516
#         ],
#         "checksum": "5dbe100c-fe5e-7963-a4f4-9a99b970b2d3"
#     },
#     {
#         "id": 192652,
#         "artworks": [
#             69304
#         ],
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "cover": 259422,
#         "created_at": 1646303210,
#         "external_games": [
#             2236011,
#             2272553
#         ],
#         "game_modes": [
#             {
#                 "game_modes_id": "1",
#                 "game_modes_value": "Single player"
#             }
#         ],
#         "genres": [
#             {
#                 "genres_id": "12",
#                 "genres_value": "Role-playing (RPG)"
#             },
#             {
#                 "genres_id": "13",
#                 "genres_value": "Simulator"
#             },
#             {
#                 "genres_id": "31",
#                 "genres_value": "Adventure"
#             },
#             {
#                 "genres_id": "32",
#                 "genres_value": "Indie"
#             }
#         ],
#         "name": "Out of Orbit",
#         "screenshots": [
#             745266,
#             745268,
#             745269,
#             745270,
#             745271,
#             745272,
#             745273
#         ],
#         "similar_games": [
#             25311,
#             26574,
#             28309,
#             29348,
#             30245,
#             35994,
#             80916,
#             96217,
#             106987,
#             113360
#         ],
#         "slug": "out-of-orbit",
#         "summary": "Design, build and manage your very own spacecraft. Explore unlimited amounts of randomly generated universes, travel through wormholes, do missions, survive cosmic events, collect and trade materials, win epic bossfights and many, many more things to do. The sky is the limit. Literally.",
#         "tags": [
#             1,
#             268435468,
#             268435469,
#             268435487,
#             268435488
#         ],
#         "themes": [
#             1
#         ],
#         "updated_at": 1697957377,
#         "url": "https://www.igdb.com/games/out-of-orbit",
#         "websites": [
#             267383,
#             485224
#         ],
#         "checksum": "1f45d045-f28b-d775-c857-bbd8bf584d4c",
#         "language_supports": [
#             "English"
#         ],
#         "steam": "1859990",
#         "reviews": [
#             {
#                 "review": "I've been having fun, but it is definately a work-in-progress. Accept that things will not always work like you want....and accept that the auto-save function will NOT save everything the way it was if you re-load...items missing...loot missing...in fact, imho, turn OFF the auto-save. and decide for yourself when to backup your game. I've had 2 games ruined by autosave to the point i had to restart. Other than that, having a blast!",
#                 "author": "wyverlunder",
#                 "recommended": true,
#                 "postedDate": "20 October"
#             },
#             {
#                 "review": "super epic game cool \ud83d\udc4d\ud83d\udc4d\ud83d\udc4d",
#                 "author": "nuttyproff",
#                 "recommended": true,
#                 "postedDate": "20 October"
#             },
#             {
#                 "review": "Awesome space game to sink your time into. Great start to EA. Looking forward to seeing where the devs take the game. Highly recommend.",
#                 "author": "YUKOTHEGREAT",
#                 "recommended": true,
#                 "postedDate": "21 October"
#             },
#             {
#                 "review": "The game is worth the price because it has a lot of great mechanics like building and upgrading your space ship, doing missions and mining for resources. Has nice combat as well with many sandbox/open space elements. But its definetly only for people who likes this niche type of games until full releasehttps://www.youtube.com/watch?v=bzJQCD4NUowNow for the cons... controls are terrible, i hope they implement moving with W in the direction of the mouse, the early access package doesn't explain the scope of the game and the start is very slow.Overall, the game needs more quality of life changes, better and bigger UI, more precise controls and more clear upgrades/consumables",
#                 "author": "Neyreyan_Youtube",
#                 "recommended": true,
#                 "postedDate": "21 October\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSteam Key"
#             },
#             {
#                 "review": "so far so good active development and a fun game to boot , come on in and play",
#                 "author": "JimmyTheDeath",
#                 "recommended": true,
#                 "postedDate": "8 November"
#             },
#             {
#                 "review": "Only taking a break to eat this is addictive I know i only got 2 hours here but i played the test before game was out.. This is a dream come true for sci-fi action and co-op will be great with my friends it's planned for sure :)",
#                 "author": "vitowns",
#                 "recommended": true,
#                 "postedDate": "29 October\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSteam Key"
#             },
#             {
#                 "review": "not the best not the worst",
#                 "author": "laser82",
#                 "recommended": true,
#                 "postedDate": "6 November"
#             },
#             {
#                 "review": "Very nice game, you start out in the middle of nowhere and you can build your ship as you like with block/tiles/objects. Then you are free to go around doing pirate stuff, mining, and much more. The game is still in early access and as such has some bugs here and there, but it is already quite deep and detailed. As a plus, the developer is very active with the comunity, releasing bugfixes immediately and listening to the feedback. Absolutely loving this game, I wish I had more time to play!",
#                 "author": "borbalf",
#                 "recommended": true,
#                 "postedDate": "29 October"
#             }
#         ]
#     },
#     {
#         "id": 200398,
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "collection": 7856,
#         "cover": 229130,
#         "created_at": 1651762811,
#         "external_games": [
#             2437812
#         ],
#         "first_release_date": 883526400,
#         "genres": [
#             {
#                 "genres_id": "14",
#                 "genres_value": "Sport"
#             }
#         ],
#         "involved_companies": [
#             170400
#         ],
#         "keywords": [
#             30750,
#             33125
#         ],
#         "name": "Fishing Champion",
#         "platforms": [
#             {
#                 "platforms_id": "411",
#                 "platforms_value": "Handheld Electronic LCD"
#             }
#         ],
#         "release_dates": [
#             389506
#         ],
#         "similar_games": [
#             109606,
#             114286,
#             116349,
#             116350,
#             116351,
#             116352,
#             116353,
#             217639,
#             217640,
#             217644
#         ],
#         "slug": "fishing-champion",
#         "tags": [
#             268435470,
#             536901662,
#             536904037
#         ],
#         "updated_at": 1671013301,
#         "url": "https://www.igdb.com/games/fishing-champion",
#         "websites": [
#             490958
#         ],
#         "checksum": "f9ee645d-949f-eed7-84c1-9f65865c04d9",
#         "companies": [
#             {
#                 "company_id": 34064,
#                 "company_name": "Tiger Electronics"
#             }
#         ]
#     },
#     {
#         "id": 130742,
#         "category": {
#             "category_id": "0",
#             "category_value": "main_game"
#         },
#         "cover": 127228,
#         "created_at": 1582360606,
#         "external_games": [
#             1807386,
#             1914612
#         ],
#         "hypes": 1,
#         "name": "Flashy Maze",
#         "slug": "flashy-maze",
#         "updated_at": 1670969862,
#         "url": "https://www.igdb.com/games/flashy-maze",
#         "websites": [
#             389076
#         ],
#         "checksum": "7394f5f1-d9f6-ddd4-f6c6-b4a3403e18bc"
#     }
# ]

# %%
# salvataggio dataset finale su file
with open("./../dataset/raw_dataset_post_age_ratings.json","w") as f:
    f.write(json.dumps(json_data_raw, indent = 4))

# %% [markdown]
# ### Posted Date Formatting

# %%
# Chiamare la funzione per trasformare la struttura del JSON
json_data = transform_json_structure(json_data_raw)

# %%
import re
from datetime import datetime

# Funzione per pulire e riformattare la data
def clean_and_format_date(date_str):
    # Rimuovi caratteri speciali e parole non necessarie
    cleaned_date = re.sub(r'[\t\n\r]|Steam Key', '', date_str).strip()

    # Tenta di convertire la data nel formato desiderato
    try:
        # Se la data ha solo mese e giorno, aggiungi l'anno corrente (2023)
        if len(cleaned_date.split(',')) == 1:
            cleaned_date += ', 2023'
        # Riformatta la data
        formatted_date = datetime.strptime(cleaned_date, '%d %B, %Y').strftime('%Y-%m-%d')
        return formatted_date
    except ValueError:
        # Se c'è un errore nella conversione, restituisci la stringa originale
        return date_str

# Elabora ogni elemento del dataset
for item in json_data:
    if 'reviews' in item and isinstance(item['reviews'], list):
        for review in item['reviews']:
            if 'postedDate' in review:
                review['postedDate'] = clean_and_format_date(review['postedDate'])

# %%
# Salvare il nuovo JSON
with open("./../dataset/games_dataset_definitive.json", 'w', encoding='utf-8') as file:
    json.dump(json_data, file, indent=4)

# %%
import json

# Carica il dataset JSON definitivo
with open('./../dataset/games_dataset_definitive.json', 'r') as file:
    json_data = json.load(file)

# %% [markdown]
# ### Extract subset of fields from dataset

# %%
import json

# List of keys to keep in the filtered dataset
keys_to_keep = [
    "age_ratings",
    "category",
    "first_release_date",
    "game_modes",
    "genres",
    "id",
    "name",
    "companies",
    "language_supports",
    "platforms",
    "reviews",
    "status",
    "summary",
    "total_rating",
    "total_rating_count",
]


#def filter_dataset(dataset, keys):
#    # Filter the dataset
#    filtered_dataset = [{key: item.get(key) for key in keys} for item in dataset]
#    return filtered_dataset

def filter_dataset(dataset, keys):
    # Check for non-null values before filtering
    non_null_counts = {key: 0 for key in keys_to_keep}
    for item in dataset:
        for key in keys_to_keep:
            if key in item and item[key] is not None:
                non_null_counts[key] += 1

    # Print the non-null counts
    for key, count in non_null_counts.items():
        print(f'Key "{key}" has {count} non-null values.')

    # Filter the dataset
    filtered_dataset = [{key: item.get(key) for key in keys if key in item} for item in dataset]
    return filtered_dataset

# Invoke the filter function
json_data_filtered = filter_dataset(json_data, keys_to_keep)
# Out:
# Key "age_ratings" has 58661 non-null values.
# Key "category" has 259290 non-null values.
# Key "first_release_date" has 164967 non-null values.
# Key "game_modes" has 139982 non-null values.
# Key "genres" has 209590 non-null values.
# Key "id" has 259290 non-null values.
# Key "name" has 259290 non-null values.
# Key "companies" has 99957 non-null values.
# Key "language_supports" has 122872 non-null values.
# Key "platforms" has 174749 non-null values.
# Key "reviews" has 88016 non-null values.
# Key "status" has 16300 non-null values.
# Key "summary" has 220787 non-null values.
# Key "total_rating" has 34899 non-null values.
# Key "total_rating_count" has 34899 non-null values.

# %%
import json
# eventually save the filtered dataset to a file
with open("../dataset/games_dataset_filtered.json", 'w') as file:
    json.dump(json_data_filtered, file, indent=4)

# %% [markdown]
# ### Mapping the clustered authors

# %%
import json
import pandas as pd
import random

# Load the mappings from the CSV
mapping_df = pd.read_csv('../dataset/Mapping-Authors.csv')
# Create a dictionary from the mappings DataFrame
author_mapping = dict(zip(mapping_df['original'], mapping_df['clustered']))

# Function to update the author names in the reviews
def update_author_names(dataset, author_mapping):
    for item in dataset:
        # Check if 'reviews' key exists and is a list
        if 'reviews' in item and isinstance(item['reviews'], list):
            for review in item['reviews']:
                # If the author of a review is in the mapping, update the name
                if 'author' in review and (review['author'] in author_mapping or review['author'] == ''):
                    review['author'] = random.choice(list(author_mapping.values())) if review["author"] == "" else str(author_mapping[review['author']])
    return dataset

# Update the author names
updated_dataset = update_author_names(json_data_filtered, author_mapping)

# %%
# eventually save the mapped dataset to a file
with open("../dataset/games_dataset_filtered_mapped.json", 'w', encoding='utf-8') as file:
    json.dump(updated_dataset, file, ensure_ascii=False, indent=4)

# %%
import json

# Carica il dataset JSON definitivo
with open('../dataset/games_dataset_filtered_mapped.json', 'r', encoding='utf-8') as file:
    json_data = json.load(file)

# %% [markdown]
# ## Preliminary analysis

# %% [markdown]
# ### List of the fields

# %% [markdown]
# Before diving into the code, let's give a look to the fields and the type of data that each of them contains (The following code performs a kind of SELECT DISTINCT of the fields):
#
# **NOTE!** 🟢
# The field "*Example Content*" contains 5 random samples of the field content. These samples are not aggregated.

# %% [markdown]
# | **FIELD** 	| **TYPE** 	| **TO PARSE** 	| **Are we going to use it?** 	| **Example Content** 	|
# |---	|:---:	|:---:	|:---:	|---	|
# | age_ratings 	|  	| 🟠 	| ✅ 	| [[114607, 114609, 126972, 126973, 126974, 127011], [39395, 54394], [65532], [67799], [57121, 58326, 91135, 93494, 110841, 126135]] 	|
# | aggregated_rating 	| float 	|  	| ❌ 	| [65.0, 73.25, 82.5, 69.0, 70.93333333333334] 	|
# | aggregated_rating_count 	|  	|  	| ❌ 	| [3, 4, 3, 1, 17] 	|
# | alternative_names 	|  	|  	| ❌ 	| [[36941, 36942, 127468], [65648, 105850, 117666], [120224], [97398], [106570, 116583]] 	|
# | artworks 	|  	|  	| ❌ 	| [[96775], [14195], [9728], [115992], [11731, 68424]] 	|
# | bundles 	|  	|  	| ❌ 	| [[263897], [230749, 230823, 230826], [251322], [29208], [136262, 164674, 164778, 219003, 230498, 230702]] 	|
# | category 	|  	| 🟢 	| ✅ 	| [0, 0, 0, 0, 0] 	|
# | checksum 	|  	|  	| ❌ 	| ['4e87d634-9146-2025-b09b-9e4ea1e04764', '00e38d21-91cd-3082-4737-7978c44e33e2', '40916ead-d6e4-99f3-ab54-d653605a984b', '489ad4d0-e2f2-09e0-3bae-a76091559c44', 'bc043ffb-ad60-6bd0-801b-55a6141e773c'] 	|
# | collection 	|  	| 🟠 	|  	| [602, 2449, 7103, 7856, 559] 	|
# | collections 	|  	| 🟠 	|  	| [[602], [18], [18], [39, 7197], [39]] 	|
# | cover 	|  	|  	| ❌ 	| [280467, 247255, 272120, 192106, 326638] 	|
# | created_at 	|  	|  	| ❌ 	| [1673878007, 1621112209, 1499434349, 1517405808, 1521818623] 	|
# | dlcs 	| game_id 	|  	|  	| [[171610], [8219, 222679, 239352], [172092], [212363, 212364, 212365], [140056, 140057, 140058]] 	|
# | expanded_games (?) 	| game_id 	|  	|  	| [[135286], [30251], [78807], [57658], [124492]] 	|
# | expansions (?) 	| game_id 	|  	|  	| [[171428], [19540, 19551, 26852], [44596], [171147], [18442]] 	|
# | external_games 	|  	| game_id of other platforms 	| ❌ 	| [[2639959, 2677882, 2677897, 2677919, 2678595], [2011978], [51807, 154169, 1867507], [221231, 1748471, 1991656], [1989881]] 	|
# | first_release_date 	|  	|  	| ✅ 	| [1677110400, 1610928000, 1019001600, 1559952000, 1644796800] 	|
# | follows 	|  	| followers of the game 	|  	| [1, 1, 1, 63, 244] 	|
# | forks (?) 	|  	|  	|  	| [[79074, 109134, 133635, 147176, 151170, 176876, 197828, 246736, 255413], [235313], [141686], [67248], [142289]] 	|
# | franchise 	|  	| 🟠 	|  	| [361, 9, 102, 299, 105] 	|
# | franchises 	|  	| 🟠 	|  	| [[1651, 3134], [872, 874], [3390], [509, 977], [1351]] 	|
# | game_engines 	|  	| 🟠 	| ❌ 	| [[1543], [427], [439], [72], [10]] 	|
# | game_localizations 	|  	| 🟠 	| ❌ 	| [[2026, 13450], [4006, 19440], [14535], [1863, 3984], [11783, 20873]] 	|
# | game_modes 	|  	| 🟢 	| ✅ 	| [[1, 2], [1, 2], [1], [1], [1]] 	|
# | genres 	|  	| 🟢 	| ✅ 	| [[15], [4, 31, 33], [7, 13, 33], [9, 33], [31, 32]] 	|
# | hypes 	|  	| number of followers before release date 	| ❌ 	| [1, 1, 26, 2, 2] 	|
# | id 	| game_id 	| id_of_IGDB 	| ✅ 	| [231577, 147666, 44711, 85450, 95080] 	|
# | companies 	|  	| 🟢 	| ✅ 	|   	|
# | keywords 	|  	|  	| ❌ 	| [[1699, 2152, 4137, 4438, 5029, 5188, 5189, 10098, 13115], [101], [78, 394, 960, 1033, 2458], [30750, 33125], [1308, 3257]] 	|
# | language_supports 	|  	| 🟠 	| ✅ 	| [[504844], [784416, 784417, 784418, 784419], [108775, 108776], [430843, 430844, 430845], [46076, 46078, 46080, 46082, 46084, 46086, 46088, 46090, 46092, 46094, 46096, 46098, 46100, 46102, 46104, 46106, 46108, 46110, 46112, 46114, 148503, 148505, 148507, 148513, 148515]] 	|
# | multiplayer_modes 	|  	|  	| ❌ 	| [[11174, 11175], [18654], [20006], [7037, 7982, 12750, 21945], [22267]] 	|
# | name 	|  	|  	| ✅ 	| ['Blood Bowl 3: Black Orcs Edition', 'Shinobi Blade', 'DDRMax2: Dance Dance Revolution', 'Transformers Prime: The Game', 'Dotra'] 	|
# | parent_game 	| game_id 	|  	|  	| [110980, 46584, 198295, 231152, 107843] 	|
# | platforms 	|  	| 🟢 	| ✅ 	| [[49, 169], [130], [8, 52], [34, 39], [6]] 	|
# | player_perspectives 	|  	|  	| ❌ 	| [[6], [2, 4], [1, 7], [1], [2]] 	|
# | ports 	|  	|  	| ❌ 	| [[73949, 144894], [10], [251353], [122871], [8809]] 	|
# | rating 	|  	|  	| ❌ 	| [70.0, 78.83709512164174, 60.0, 40.0, 50.0] 	|
# | rating_count 	|  	|  	| ❌ 	| [0, 102, 0, 0, 0] 	|
# | release_dates 	|  	|  	| ❌ 	| [[455316, 455317], [249798, 340666], [201923, 201924, 201925], [511087], [345917, 387770, 387772, 387773, 389364, 406085]] 	|
# | remakes 	|  	|  	| ❌ 	| [[18189], [222995], [93192], [1181], [245057]] 	|
# | remasters 	|  	|  	| ❌ 	| [[265060], [145817, 158981], [11218], [203435], [267307]] 	|
# | reviews.author 	|  	|  	| ✅ 	| ['maskedgingerjock', 'MisterEcho', 'Ziggy The Adventurer', 'Obey the Fist!', 'Sixth'] 	|
# | reviews.postedDate 	|  	|  	| ✅ 	| ['18 September', '4 September', '3 September', '31 March, 2022\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSteam Key', '21 September, 2022'] 	|
# | reviews.recommended 	|  	|  	| ✅ 	| [False, True, None, False, True] 	|
# | reviews.review 	|  	|  	| ✅ 	| ['This game is horrible. This game is boring.You can get both endings in under 10 minutes.There is no ...', 'https://youtu.be/dbbmoI0O5UgPretty nice game if you like indie walking simulator games with some jum...', "Plays fine, looks okay, very limited options, no body, can't jump or crouch, can be finished in abou...", 'Warning: Asset Flip!Pet Puzzle is a Unity Asset flip, what Valve calls a "fake game". 	|
# | screenshots 	|  	|  	| ❌ 	| [[1002202, 1002203, 1002204, 1002205, 1002206, 1002207], [447897, 447898, 447899, 447900, 447901], [338676, 338677, 338678, 390639, 390640], [1128097, 1128099, 1128104, 1128107, 1128111], [311510, 311511, 311512, 311513, 311514]] 	|
# | similar_games 	| game_id 	|  	|  	| [[17613, 24620, 36269, 36346, 65827, 76340, 77038, 77597, 111043, 112754], [10605, 56033, 87622, 96217, 101608, 103292, 103369, 111130, 114145, 117533], [3679, 18981, 27378, 38967, 43218, 43488, 43680, 63933, 73042, 76901], [18115, 19222, 25905, 41349, 85804, 87170, 87507, 90788, 90965, 95776], [13189, 25222, 27266, 55282, 75948, 87975, 96217, 106992, 111130, 121217]] 	|
# | slug 	|  	|  	| ❌ 	| ['blood-bowl-3-black-orcs-edition', 'shinobi-blade', 'ddrmax2-dance-dance-revolution', 'transformers-prime-the-game', 'dotra'] 	|
# | standalone_expansions 	|  	|  	| ❌ 	| [[146969], [3735], [27898], [203628], [128415]] 	|
# | status 	|  	| 🟢 	| ✅ 	| [8, 4, 4, 4, 4] 	|
# | steam 	|  	|  	| ❌ 	| ['2557720', '1092080', '1667954', '1851020', '2009730'] 	|
# | storyline 	|  	|  	| ❌ 	| ['In the ancient, mysterious world of the Jade Empire, you train under your master’s watchful eye and ...', 'From the frigid climes of Norsca to the arid wastes of the southern Badlands, The Old World echoes t...', 'You live in a peaceful world that has triumphed over a giant alien invasion. To pay off your debts, ...', "You who are unqualified to drink Meng Po's soup, you have been chosen for the game of life. Three wo...", 'Following the end of the Galactic Civil War, the bright lights of The Arena burst into life and offe...'] 	|
# | summary 	|  	|  	| ✅ 	| ["Fashion is not exactly a priority for Black Orcs… but intimidation, on the other hand, now we're tal...", 'Shinobi Blade is an action-packed game, lets you play the role of a teenage ninja who sneaked out of...', 'The dance floor kicks into overdrive with DDRMAX2 Dance Dance Revolution. It is the latest installme...', 'Shoot bubbles and match colors to pop your way up to victory in this bubble shooting adventure, win ...', 'A missing father, a mysterious murder, paintings depicting missing children. Horror game in which th...'] 	|
# | tags 	|  	|  	| ❌ 	| [[268435471], [1, 268435460, 268435487, 268435489], [40, 268435463, 268435469, 268435489, 536872611, 536873064, 536875049, 536875350, 536875941, 536876100, 536876101, 536881010, 536884027], [268435465, 268435489], [268435487, 268435488]] 	|
# | themes 	|  	|  	| ❌ 	| [[1], [40], [17, 22, 27], [1], [1]] 	|
# | total_rating 	|  	|  	| ✅ 	| [65.0, 70.0, 73.25, 80.66854756082087, 60.0] 	|
# | total_rating_count 	|  	|  	| ✅ 	| [3, 0, 4, 105, 0] 	|
# | updated_at 	|  	|  	| ❌ 	| [1699266775, 1698219001, 1696215459, 1670993154, 1670992528] 	|
# | url 	|  	|  	| ❌ 	| ['https://www.igdb.com/games/blood-bowl-3-black-orcs-edition', 'https://www.igdb.com/games/shinobi-blade', 'https://www.igdb.com/games/ddrmax2-dance-dance-revolution', 'https://www.igdb.com/games/transformers-prime-the-game', 'https://www.igdb.com/games/dotra'] 	|
# | version_parent 	|  	|  	| ❌ 	| [138137, 24115, 139736, 138137, 28856] 	|
# | version_title 	|  	|  	| ❌ 	| ['Black Orcs Edition', 'Platinum Edition', "Collector's Edition", 'Imperial Nobility Edition', 'Digital Deluxe Edition'] 	|
# | videos 	|  	|  	| ❌ 	| [[37984], [64610], [28099], [35464], [28553]] 	|
# | websites 	|  	|  	| ❌ 	| [[455726], [145653, 145654, 145655, 354472], [445624], [429116], [407422]] 	|

# %%
def explore_keys_with_examples(data, path='', examples=None):
    """
    Funzione ricorsiva per esplorare le chiavi in un dataset JSON e raccogliere esempi.
    
    :param data: Il dataset o una parte di esso.
    :param path: Il percorso corrente delle chiavi.
    :param examples: Un dizionario che tiene traccia degli esempi per ogni chiave.
    :return: None. Modifica il dizionario `examples` direttamente.
    """
    if examples is None:
        examples = {}

    if isinstance(data, dict):
        for k, v in data.items():
            new_path = f"{path}.{k}" if path else k
            if new_path not in examples:
                examples[new_path] = []
            if len(examples[new_path]) < 5:
                # Tronca il testo se è troppo lungo
                if isinstance(v, str) and len(v) > 100:
                    v = v[:100] + "..."
                examples[new_path].append(v)
            explore_keys_with_examples(v, new_path, examples)

    elif isinstance(data, list):
        for item in data:
            explore_keys_with_examples(item, path, examples)

    return examples

# Esplora le chiavi e raccogli esempi
examples = explore_keys_with_examples(json_data)

# Stampa i risultati
for key in sorted(examples):
    print(f"{key}: {examples[key]}")
    #print(f"{examples[key]}")

# %% [markdown]
# ### Count objects with particular fields

# %%
count_games = sum(1 for item in json_data)
count_without_companies = sum(1 for item in json_data if 'companies' not in item)
count_without_involved_companies = sum(1 for item in json_data if 'involved_companies' not in item)

x = sum(1 for item in json_data if 'involved_companies' in item and 'companies' not in item)

y = sum(len(item['language_supports']) for item in json_data if 'language_supports' in item)
j = sum(len(item['language_supports']) for item in json_data_raw.values() if 'language_supports' in item)
z = sum(len(item['age_ratings']) for item in json_data_raw.values() if 'age_ratings' in item)

reviews = sum(len(item['reviews']) for item in json_data if 'reviews' in item)

print(f"Numero di giochi: {count_games}")
print(f"Numero di oggetti senza la chiave 'companies': {count_without_companies}")
print(f"Numero di oggetti senza la chiave 'involved_companies': {count_without_involved_companies}")
print(f"Numero di oggetti con la chiave 'involved_companies' ma senza 'companies': {x}")
print(f"Language supports tot: {y}")
print(f"Language supports raw tot: {j}")
print(f"Age ratings raw tot: {z}")

print(f"Numero di reviews: {reviews}")
# Out:
# Numero di giochi: 259290
# Numero di oggetti senza la chiave 'companies': 159333
# Numero di oggetti senza la chiave 'involved_companies': 259290
# Numero di oggetti con la chiave 'involved_companies' ma senza 'companies': 0
# Language supports tot: 122872
# Language supports raw tot: 811759
# Age ratings raw tot: 127784
# Numero di reviews: 510061

# %% [markdown]
# ### Distinct list of elements of a particular field

# %%
def extract_unique_elements_from_field(json_data, field_name):
    """
    Estrae elementi unici da un campo specificato in un dataset JSON.

    :param json_data: Il dataset JSON (lista di dizionari).
    :param field_name: Il nome del campo da cui estrarre gli elementi.
    :return: Un set di elementi unici.
    """
    unique_elements = set()

    for item in json_data:
        if field_name in item and isinstance(item[field_name], list):
            unique_elements.update(item[field_name])

    return unique_elements


# Scegli il campo da cui estrarre gli elementi
field_to_extract = "involved_companies"

# Estrai gli elementi unici
unique_elements = extract_unique_elements_from_field(json_data, field_to_extract)

# Stampa i risultati
print(f"{unique_elements}")

# %% [markdown]
# ### Reviews Extraction

# %%
# estrazione delle reviews
import json

def extract_reviews_from_json(json_data):
    """
    Estrae tutte le recensioni univoche da un dataset JSON.

    :param json_data: Il dataset JSON (lista di dizionari).
    :return: Una lista di oggetti recensione univoci.
    """
    reviews = []

    for item in json_data:
        if 'reviews' in item and isinstance(item['reviews'], list):
            for review in item['reviews']:
                # Assumi che ogni recensione sia un dizionario e aggiungi l'ID del gioco
                review_with_id = review  # Fai una copia se non vuoi modificare l'originale
                review_with_id['game_id'] = item['id']  # Aggiungi l'ID del gioco
                reviews.append(review_with_id)

    return reviews

# Estrai le recensioni
extracted_reviews = extract_reviews_from_json(json_data)

# Scrivi le recensioni estratte in un nuovo file JSON
with open("../dataset/reviews.json", 'w', encoding='utf-8') as file:
    json.dump(extracted_reviews, file, ensure_ascii=False, indent=4)

# %% [markdown]
# ## Content analysis

# %%
import pandas as pd

df = pd.json_normalize(json_data)

# Visualizza le prime righe del dataset
print(df.head())

# Informazioni sul dataset
print(df.info())

# Statistiche descrittive
print(df.describe())

# Conteggio valori nulli
print(df.isnull().sum())

# %% [markdown]
# ### Genres analysis

# %%
from matplotlib import pyplot as plt
import seaborn as sns

genre_counts = df['genres'].explode().value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=genre_counts.index, y=genre_counts.values)
plt.title('Distribuzione dei Generi di Giochi')
plt.xlabel('Genere')
plt.ylabel('Conteggio')
plt.show()

# Analisi delle piattaforme
# Codice simile può essere usato per analizzare le piattaforme
